# %% [markdown]
# ### Import Library

# %%
# 이 중에서 안깔린 라이브러리가 있을 수 있음
import sys
import os
from typing import List, Dict, Tuple
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
import lightgbm as lgb
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from sklearn.preprocessing import QuantileTransformer


import seaborn as sns
import matplotlib.pyplot as plt
import pywt

sys.path.append(os.path.abspath('../'))  # 알아서 수정해 쓸 것
from func.utils import evaluate_model
import func.features as ft

from lightgbm import LGBMClassifier
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# ### Load Data

# %%
path = "../../../data/" # 본인 작업환경에 맞게 변경

train = pd.read_csv(path+"train.csv").assign(_type="train")
test = pd.read_csv(path+"test.csv").assign(_type="test")
submission = pd.read_csv(path+"test.csv")
df = pd.concat([train, test], axis=0)

# HOURLY_ 로 시작하는 .csv 파일 이름을 file_names 에 할딩
file_names: List[str] = [
    f for f in os.listdir(path) if f.startswith("HOURLY_") and f.endswith(".csv")
]

# 파일명 : 데이터프레임으로 딕셔너리 형태로 저장
file_dict: Dict[str, pd.DataFrame] = {
    f.replace(".csv", ""): pd.read_csv(os.path.join(path, f)) for f in file_names
}

for _file_name, _df in tqdm(file_dict.items()):
    # 열 이름 중복 방지를 위해 {_file_name.lower()}_{col.lower()}로 변경, datetime 열을 ID로 변경
    _rename_rule = {
        col: f"{_file_name.lower()}_{col.lower()}" if col != "datetime" else "ID"
        for col in _df.columns
    }
    _df = _df.rename(_rename_rule, axis=1)
    df = df.merge(_df, on="ID", how="left")
# Out:
# 100%|██████████| 107/107 [00:03<00:00, 31.33it/s]

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# hourly_market-data_open-interest_gate_io_open_interest                11552
# hourly_market-data_taker-buy-sell-stats_okex_taker_buy_volume         11552
# hourly_market-data_open-interest_bitmex_open_interest                 11552
# hourly_market-data_taker-buy-sell-stats_okex_taker_sell_volume        11552
# hourly_market-data_taker-buy-sell-stats_okex_taker_buy_ratio          11552
#                                                                       ...
# hourly_market-data_open-interest_htx_global_btc_usdt_open_interest        0
# hourly_network-data_blockreward_blockreward_usd                           0
# hourly_network-data_blockreward_blockreward                               0
# _type                                                                     0
# ID                                                                        0
# Length: 255, dtype: int64

# %%
# 결측치 처리 - 칼럼 정리 

# 결측치 확인 및 처리를 위해 train, test로 분리 
train_df = df[df['_type'] == 'train']
test_df = df[df['_type'] == 'test']

# 결측치 많은 칼럼 확인
train_drop_cols = train_df.columns[train_df.isnull().sum() > 4000].tolist()
test_drop_cols = test_df.iloc[:, 2:].columns[test_df.iloc[:, 2:].isnull().sum() > 2000].tolist()
total_drop_cols = set(train_drop_cols).union(set(test_drop_cols))

# 결측치 많은 칼럼 제거 후 train, test 다시 병합
train_df = train_df.drop(total_drop_cols,axis=1)
test_df = test_df.drop(total_drop_cols,axis=1)

# %%
# 복사해서 보간 진행
tmp_train_df = train_df.drop(['ID', 'target', '_type'], axis=1).copy()
tmp_test_df = test_df.drop(['ID', 'target', '_type'], axis=1).copy()

# 결측치 처리 - 선형 보간법 (linear interpolation)
train_df_interpolated = tmp_train_df.interpolate(method='linear')
test_df_interpolated = tmp_test_df.interpolate(method='linear')

# 학습/테스트 데이터 부분 업데이트
train_df.update(train_df_interpolated)
test_df.update(test_df_interpolated)

# 결측치 처리 후 확인
print(train_df.isnull().sum())
print(test_df.isnull().sum())

# df로 다시 합치기
df= pd.concat([train_df, test_df], axis = 0)
# Out:
# ID                                                                           0
# target                                                                       0
# _type                                                                        0
# hourly_market-data_taker-buy-sell-stats_bybit_taker_buy_volume               0
# hourly_market-data_taker-buy-sell-stats_bybit_taker_sell_volume              0
#                                                                             ..
# hourly_market-data_open-interest_okx_all_symbol_open_interest                0
# hourly_market-data_liquidations_gate_io_all_symbol_long_liquidations         0
# hourly_market-data_liquidations_gate_io_all_symbol_short_liquidations        0
# hourly_market-data_liquidations_gate_io_all_symbol_long_liquidations_usd     0
# hourly_market-data_liquidations_gate_io_all_symbol_short_liquidations_usd    0
# Length: 208, dtype: int64
# ID                                                                              0
# target                                                                       2792
# _type                                                                           0
# hourly_market-data_taker-buy-sell-stats_bybit_taker_buy_volume                  0
# hourly_market-data_taker-buy-sell-stats_bybit_taker_sell_volume                 0
#                                                                              ...
# hourly_market-data_open-interest_okx_all_symbol_open_interest                   0
# hourly_market-data_liquidations_gate_io_all_symbol_long_liquidations            0
# hourly_market-data_liquidations_gate_io_all_symbol_short_liquidations           0
# hourly_market-data_liquidations_gate_io_all_symbol_long_liquidations_usd        0
# hourly_market-data_liquidations_gate_io_all_symbol_short_liquidations_usd       0
# Length: 208, dtype: int64

# %%
df= pd.concat([train_df, test_df], axis = 0)

# %%
def get_columns_with_many_zeros(df, threshold_ratio=0.5):
    """
    주어진 임계값 비율 이상의 0을 가진 열을 반환합니다.
    
    :param df: 데이터프레임
    :param threshold_ratio: 0의 비율 임계값 (기본값: 0.5, 즉 50%)
    :return: 임계값 이상의 0을 가진 열 이름 리스트
    """
    # 각 열에서 0의 개수를 계산
    zero_counts = (df == 0).sum()
    
    # 전체 행 수 대비 0의 비율 계산
    zero_ratios = zero_counts / len(df)
    
    # 임계값 이상의 0 비율을 가진 열 선택
    columns_with_many_zeros = zero_ratios[zero_ratios >= threshold_ratio].index.tolist()
    
    return columns_with_many_zeros

# 사용 예시
# df는 여러분의 데이터프레임입니다
columns_with_many_zeros = get_columns_with_many_zeros(df, threshold_ratio=0.5)
print("0이 많은 컬럼:", columns_with_many_zeros)

# 0이 많은 컬럼의 비율 출력
zero_ratios = (df == 0).sum() / len(df)
for col in columns_with_many_zeros:
    print(f"{col}: {zero_ratios[col]:.2%}")
print(len(columns_with_many_zeros))
# Out:
# 0이 많은 컬럼: ['hourly_market-data_liquidations_htx_global_btc_usd_long_liquidations', 'hourly_market-data_liquidations_htx_global_btc_usd_short_liquidations', 'hourly_market-data_liquidations_htx_global_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_htx_global_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_bybit_btc_usdt_long_liquidations', 'hourly_market-data_liquidations_bybit_btc_usdt_short_liquidations', 'hourly_market-data_liquidations_bybit_btc_usdt_long_liquidations_usd', 'hourly_market-data_liquidations_bybit_btc_usdt_short_liquidations_usd', 'hourly_market-data_liquidations_gate_io_btc_usd_long_liquidations', 'hourly_market-data_liquidations_gate_io_btc_usd_short_liquidations', 'hourly_market-data_liquidations_gate_io_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_gate_io_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_okx_btc_usd_long_liquidations', 'hourly_market-data_liquidations_okx_btc_usd_short_liquidations', 'hourly_market-data_liquidations_okx_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_okx_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_bybit_btc_usd_long_liquidations', 'hourly_market-data_liquidations_bybit_btc_usd_short_liquidations', 'hourly_market-data_liquidations_bybit_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_bybit_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_deribit_btc_usd_long_liquidations', 'hourly_market-data_liquidations_deribit_btc_usd_short_liquidations', 'hourly_market-data_liquidations_deribit_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_deribit_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_bitfinex_btc_usdt_long_liquidations', 'hourly_market-data_liquidations_bitfinex_btc_usdt_short_liquidations', 'hourly_market-data_liquidations_bitfinex_btc_usdt_long_liquidations_usd', 'hourly_market-data_liquidations_bitfinex_btc_usdt_short_liquidations_usd', 'hourly_market-data_liquidations_gate_io_btc_usdt_long_liquidations', 'hourly_market-data_liquidations_gate_io_btc_usdt_short_liquidations', 'hourly_market-data_liquidations_gate_io_btc_usdt_long_liquidations_usd', 'hourly_market-data_liquidations_gate_io_btc_usdt_short_liquidations_usd', 'hourly_market-data_liquidations_bitmex_btc_usd_long_liquidations', 'hourly_market-data_liquidations_bitmex_btc_usd_short_liquidations', 'hourly_market-data_liquidations_bitmex_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_bitmex_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_bitmex_all_symbol_long_liquidations', 'hourly_market-data_liquidations_bitmex_all_symbol_short_liquidations', 'hourly_market-data_liquidations_bitmex_all_symbol_long_liquidations_usd', 'hourly_market-data_liquidations_bitmex_all_symbol_short_liquidations_usd', 'hourly_market-data_liquidations_bybit_all_symbol_short_liquidations', 'hourly_market-data_liquidations_bybit_all_symbol_short_liquidations_usd', 'hourly_market-data_liquidations_deribit_all_symbol_long_liquidations', 'hourly_market-data_liquidations_deribit_all_symbol_short_liquidations', 'hourly_market-data_liquidations_deribit_all_symbol_long_liquidations_usd', 'hourly_market-data_liquidations_deribit_all_symbol_short_liquidations_usd', 'hourly_market-data_liquidations_huobi_global_btc_usd_long_liquidations', 'hourly_market-data_liquidations_huobi_global_btc_usd_short_liquidations', 'hourly_market-data_liquidations_huobi_global_btc_usd_long_liquidations_usd', 'hourly_market-data_liquidations_huobi_global_btc_usd_short_liquidations_usd', 'hourly_market-data_liquidations_bitfinex_all_symbol_long_liquidations', 'hourly_market-data_liquidations_bitfinex_all_symbol_short_liquidations', 'hourly_market-data_liquidations_bitfinex_all_symbol_long_liquidations_usd', 'hourly_market-data_liquidations_bitfinex_all_symbol_short_liquidations_usd', 'hourly_market-data_liquidations_binance_btc_usd_long_liquidations', 'hourly_ ...
# hourly_market-data_liquidations_htx_global_btc_usd_long_liquidations: 88.02%
# hourly_market-data_liquidations_htx_global_btc_usd_short_liquidations: 91.69%
# hourly_market-data_liquidations_htx_global_btc_usd_long_liquidations_usd: 88.02%
# hourly_market-data_liquidations_htx_global_btc_usd_short_liquidations_usd: 91.69%
# hourly_market-data_liquidations_bybit_btc_usdt_long_liquidations: 54.09%
# hourly_market-data_liquidations_bybit_btc_usdt_short_liquidations: 51.91%
# hourly_market-data_liquidations_bybit_btc_usdt_long_liquidations_usd: 54.09%
# hourly_market-data_liquidations_bybit_btc_usdt_short_liquidations_usd: 51.91%
# hourly_market-data_liquidations_gate_io_btc_usd_long_liquidations: 89.33%
# hourly_market-data_liquidations_gate_io_btc_usd_short_liquidations: 91.33%
# hourly_market-data_liquidations_gate_io_btc_usd_long_liquidations_usd: 89.33%
# hourly_market-data_liquidations_gate_io_btc_usd_short_liquidations_usd: 91.33%
# hourly_market-data_liquidations_okx_btc_usd_long_liquidations: 81.36%
# hourly_market-data_liquidations_okx_btc_usd_short_liquidations: 84.68%
# hourly_market-data_liquidations_okx_btc_usd_long_liquidations_usd: 81.36%
# hourly_market-data_liquidations_okx_btc_usd_short_liquidations_usd: 84.68%
# hourly_market-data_liquidations_bybit_btc_usd_long_liquidations: 58.56%
# hourly_market-data_liquidations_bybit_btc_usd_short_liquidations: 65.34%
# hourly_market-data_liquidations_bybit_btc_usd_long_liquidations_usd: 58.56%
# hourly_market-data_liquidations_bybit_btc_usd_short_liquidations_usd: 65.34%
# hourly_market-data_liquidations_deribit_btc_usd_long_liquidations: 95.52%
# hourly_market-data_liquidations_deribit_btc_usd_short_liquidations: 95.91%
# hourly_market-data_liquidations_deribit_btc_usd_long_liquidations_usd: 95.52%
# hourly_market-data_liquidations_deribit_btc_usd_short_liquidations_usd: 95.91%
# hourly_market-data_liquidations_bitfinex_btc_usdt_long_liquidations: 90.88%
# hourly_market-data_liquidations_bitfinex_btc_usdt_short_liquidations: 92.47%
# hourly_market-data_liquidations_bitfinex_btc_usdt_long_liquidations_usd: 90.88%
# hourly_market-data_liquidations_bitfinex_btc_usdt_short_liquidations_usd: 92.47%
# hourly_market-data_liquidations_gate_io_btc_usdt_long_liquidations: 60.35%
# hourly_market-data_liquidations_gate_io_btc_usdt_short_liquidations: 56.67%
# hourly_market-data_liquidations_gate_io_btc_usdt_long_liquidations_usd: 60.36%
# hourly_market-data_liquidations_gate_io_btc_usdt_short_liquidations_usd: 56.67%
# hourly_market-data_liquidations_bitmex_btc_usd_long_liquidations: 82.85%
# hourly_market-data_liquidations_bitmex_btc_usd_short_liquidations: 87.96%
# hourly_market-data_liquidations_bitmex_btc_usd_long_liquidations_usd: 82.85%
# hourly_market-data_liquidations_bitmex_btc_usd_short_liquidations_usd: 87.96%
# hourly_market-data_liquidations_bitmex_all_symbol_long_liquidations: 82.68%
# hourly_market-data_liquidations_bitmex_all_symbol_short_liquidations: 87.98%
# hourly_market-data_liquidations_bitmex_all_symbol_long_liquidations_usd: 82.68%
# hourly_market-data_liquidations_bitmex_all_symbol_short_liquidations_usd: 87.98%
# hourly_market-data_liquidations_bybit_all_symbol_short_liquidations: 50.84%
# hourly_market-data_liquidations_bybit_all_symbol_short_liquidations_usd: 50.84%
# hourly_market-data_liquidations_deribit_all_symbol_long_liquidations: 95.52%
# hourly_market-data_liquidations_deribit_all_symbol_short_liquidations: 95.91%
# hourly_market-data_liquidations_deribit_all_symbol_long_liquidations_usd: 95.52%
# hourly_market-data_liquidations_deribit_all_symbol_short_liquidations_usd: 95.91%
# hourly_market-data_liquidations_huobi_global_btc_usd_long_liquidations: 88.05%
# hourly_market-data_liquidations_huobi_global_btc_usd_short_liquidations: 91.72%
# hourly_market-data_liquidations_huobi_global_btc_usd_long_liquidations_usd: 88.05%
# hourly_market-data_liquidations_huobi_global_btc_usd_short_liquidations_usd: 91.72%
# hourly_market-data_liquidations_bitfinex_all_symbol_long_liquidations: 91.01%
# hourly_market-data_liquidations_bitfinex_all_symbol_short_liquidations: 92.54%
# hourly_market-data_liquidations_bitfinex_all_symbol_long_liquidations_usd: 91.01%
# hourly_market-data_liquidations_bitfinex_all_symbol_short_liquidations_usd: 92.54%
# hourly_market-data_liquidations_binance_btc_usd_long_liquidations: 56.94%
# hourly_market-data_liquidations_binance_btc_usd_short_liquidations: 63.56%
# hourly_market-data_liquidations_binance_btc_usd_long_liquidations_usd: 56.94%
# hourly_market-data_liquidations_binance_btc_usd_short_liquidations_usd: 63.56%
# hourly_market-data_liquidations_gate_io_all_symbol_long_liquidations: 60.01%
# hourly_market-data_liquidations_gate_io_all_symbol_short_liquidations: 56.86%
# hourly_market-data_liquidations_gate_io_all_symbol_long_liquidations_usd: 60.02%
# hourly_market-data_liquidations_gate_io_all_symbol_short_liquidations_usd: 56.86%
# 62

# %%
df.shape
# Out:
# (11552, 208)

# %%
df = df.drop(columns_with_many_zeros, axis=1)

# %%
df.shape
# Out:
# (11552, 146)

# %% [markdown]
# ### Quantile Transform

# %%
# from sklearn.preprocessing import QuantileTransformer

# # 3번째 열부터 마지막 열까지 선택
# train_df_subset = df[df['_type'] == 'train'].iloc[:, 3:]
# test_df_subset = df[df['_type'] == 'test'].iloc[:, 3:]

# # 왜도 계산
# skewness = train_df_subset.skew()

# # 임계값 설정 (0.8 이상이면 right skewed, -0.3 이하면 left skewed로 구분)
# right_skewed = skewness[skewness > 0.8].index
# left_skewed = skewness[skewness < -0.3].index

# # Quantile Transform
# quantile_transformer_right = QuantileTransformer(output_distribution='normal', random_state=0)
# quantile_transformer_left = QuantileTransformer(output_distribution='normal', random_state=0)

# # train 데이터에 fit_transform 적용
# train_df_subset[right_skewed] = quantile_transformer_right.fit_transform(train_df_subset[right_skewed])
# train_df_subset[left_skewed] = quantile_transformer_left.fit_transform(train_df_subset[left_skewed])

# # test 데이터에 transform만 적용 (train에서 fit한 값을 기반으로 변환)
# test_df_subset[right_skewed] = quantile_transformer_right.transform(test_df_subset[right_skewed])
# test_df_subset[left_skewed] = quantile_transformer_left.transform(test_df_subset[left_skewed])

# df_subset = pd.concat([train_df_subset, test_df_subset], axis=0)
# df.iloc[:, 3:] = df_subset

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# #### Received Baseline

# %%
# 불필요한 접두사 제거 
df.columns = df.columns.str.replace('hourly_market-data_|hourly_network-data_', '', regex=True)
display(df.columns)
# Out:
# Index(['ID', 'target', '_type', 'taker-buy-sell-stats_bybit_taker_buy_volume',
#        'taker-buy-sell-stats_bybit_taker_sell_volume',
#        'taker-buy-sell-stats_bybit_taker_buy_ratio',
#        'taker-buy-sell-stats_bybit_taker_sell_ratio',
#        'taker-buy-sell-stats_bybit_taker_buy_sell_ratio',
#        'taker-buy-sell-stats_all_exchange_taker_buy_volume',
#        'taker-buy-sell-stats_all_exchange_taker_sell_volume',
#        ...
#        'liquidations_htx_global_btc_usdt_short_liquidations',
#        'liquidations_htx_global_btc_usdt_long_liquidations_usd',
#        'liquidations_htx_global_btc_usdt_short_liquidations_usd',
#        'open-interest_gate_io_all_symbol_open_interest',
#        'blockreward_blockreward', 'blockreward_blockreward_usd',
#        'difficulty_difficulty', 'utxo-count_utxo_count',
#        'open-interest_binance_btc_usd_open_interest',
#        'open-interest_okx_all_symbol_open_interest'],
#       dtype='object', length=146)

# %%
# 제공된 피처 엔지니어링 적용
df = ft.make_baseline_extra(df)
df['liquidation_diff'] # 확인
# Out:
# 0        0.012000
# 1       -0.712000
# 2        0.000000
# 3        0.593000
# 4        0.361000
#            ...
# 11547    0.466500
# 11548    6.431208
# 11549   -3.419327
# 11550   -0.853000
# 11551   -1.569674
# Name: liquidation_diff, Length: 11552, dtype: float64

# %%
# 1. 날짜 피처 생성
df = ft.make_date(df, 'ID') 

# 2. Open Interest 관련 변동성, 차분 피처 생성
imp_open_interest_columns = [
    'open-interest_all_exchange_all_symbol_open_interest',
    'open-interest_binance_btc_usd_open_interest',
    'open-interest_okx_btc_usdt_open_interest',
    'open-interest_deribit_btc_usd_open_interest',
    'open-interest_deribit_all_symbol_open_interest',
    'open-interest_bybit_btc_usdt_open_interest',
    'open-interest_bitfinex_btc_usdt_open_interest',
    'open-interest_bybit_all_symbol_open_interest'
] 
df = ft.make_diff_change(df, imp_open_interest_columns) # 변동성, 차분 피처 

# 3. 롱/숏 비율
df = ft.make_liquidation_to_volume_ratio(df, 'liquidations_binance_all_symbol_long_liquidations', 'liquidations_binance_all_symbol_short_liquidations',
    'taker-buy-sell-stats_binance_taker_buy_volume', 'taker-buy-sell-stats_binance_taker_sell_volume') # 롱/숏 비율

# 4. 청산/거래량 비율
df = ft.make_liquidation_to_volume_ratio(df,'liquidations_binance_all_symbol_long_liquidations', 'liquidations_binance_all_symbol_short_liquidations',
    'taker-buy-sell-stats_binance_taker_buy_volume','taker-buy-sell-stats_binance_taker_sell_volume')

# 5. # 청산된 USD 롱/숏 비율
df = ft.make_liquidation_usd_ratio(df,'liquidations_binance_all_symbol_long_liquidations_usd','liquidations_binance_all_symbol_short_liquidations_usd')

# 6. 펀딩 비율과 롱/숏 포지션 차이 곱
df = ft.make_funding_rate_position_change(df, 'funding-rates_okx_funding_rates', 'liquidations_binance_all_symbol_long_liquidations', 
    'liquidations_binance_all_symbol_short_liquidations')

# 7. 프리미엄 갭과 프리미엄 인덱스의 차이
df = ft.make_premium_diff(df, 'coinbase-premium-index_coinbase_premium_gap', 'coinbase-premium-index_coinbase_premium_index')

# 8. 해시레이트와 난이도 간의 비율
df = ft.make_hashrate_to_difficulty(df, 'hashrate_hashrate', 'difficulty_difficulty')

# 9. 공급 변화율
df = ft.make_supply_change_rate(df, 'supply_supply_new', 'supply_supply_total')

# 10. Rolling(이동평균) 피처
df = ft.make_multiple_rolling(df, ['ID', 'target', '_type'] + ['year', 'month', 'week', 'day_of_week', 'hour'])

# %%
# 카테고리, 날짜, 롤링, 수치형 피처 분류
category_cols: List[str] = ["liquidation_diffg", "liquidation_usd_diffg", "volume_diffg"]
date_columns = ['ID', 'year', 'month', 'week', 'day_of_week', 'hour']
rolling_columns = [col for col in df.columns if 'rolling' in col]  # 'rolling'이 포함된 피처
conti_cols: List[str] = [col for col in df.columns if col not in category_cols + date_columns + rolling_columns + ['target', '_type']]

# 모든 수치형 컬럼에 대한 지수이동평균 계산
ema_dfs = []
for c in conti_cols:
    ema_df = ft.make_EMA(df, [c], 7)
    ema_df.columns = [f"{c}_moving_avg_7"]
    ema_dfs.append(ema_df)

# 원본 데이터프레임과 새로 계산된 EMA 데이터프레임들을 병합
df = pd.concat([df] + ema_dfs, axis=1)
    

# 모든 수치형 컬럼에 대한 Wavelet transform을 계산
wt_dfs = []
for c in conti_cols:
    wt_series = pd.Series(ft.make_WT(df, c), name=f"{c}_WT", index=df.index)
    wt_dfs.append(wt_series)

# 원본 데이터프레임과 새로 계산된 WT 시리즈들을 병합
df = pd.concat([df] + wt_dfs, axis=1)

# 최대 24시간의 shift 피쳐를 계산
shift_list = ft.make_shift(
    df=df, conti_cols=conti_cols, intervals=[_ for _ in [1, 2, 5, 23, 47]]
)

# %%
df = pd.concat([df, pd.concat(shift_list, axis=1)], axis=1)
_target = df["target"]
df = df.ffill().fillna(-999).assign(target = _target)
# df = df.loc[:, ~df.columns.duplicated()]
# df = df.drop(columns=new_features)

train_df = df.loc[df["_type"]=="train"].drop(columns=["_type"])
test_df = df.loc[df["_type"]=="test"].drop(columns=["_type"])

# %% [markdown]
# ### Model Training

# %%
# 칼럼 그룹 정리  (추후 실험에서 특정 피처들 포함/미포함을 쉽게 관리하기 위함. 교집합 없음)

# 기존 칼럼
addresses_columns = [col for col in df.columns if 'addresses' in col] # addresses(주소) 관련 피처. 변수명에 'addresses'포함
block_columns = [col for col in df.columns if 'block-' in col] # block(블록) 관련 피처. 변수명에 'block-' 포함 
blockreward_columns = [col for col in df.columns if 'blockreward' in col] # blockreward 관련 피처
difficulty_columns = [col for col in df.columns if 'difficulty' in col] # difficulty 관련 피처
fees_columns = [col for col in df.columns if 'fees' in col] # fees 관련 피처
hashrate_columns = [col for col in df.columns if 'hashrate' in col] # hashrate 관련 피처
supply_columns = [col for col in df.columns if 'supply_supply' in col] # supply 관련 피처
tokens_columns = [col for col in df.columns if 'tokens' in col] # tokens 관련 피처
transactions_columns = [col for col in df.columns if 'transactions' in col] # transactions 관련 피처
utxo_columns = [col for col in df.columns if 'utxo' in col] # utxo 관련 피처
velocity_columns = [col for col in df.columns if 'velocity' in col] # velocity 관련 피처
premium_columns = [col for col in df.columns if 'premium' in col] # premium 관련 피처
funding_rates_columns = [col for col in df.columns if 'funding_rates' in col] # funding rates 관련 피처
long_liquidation_columns = [col for col in df.columns if 'long_liquidation' in col] # 롱 청산 관련 피처
short_liquidation_columns = [col for col in df.columns if 'short_liquidation' in col] # 숏 청산 관련 피처
open_interest_columns = [col for col in df.columns if 'open_interest' in col] # open-interest 관련 피처
taker_columns = [col for col in df.columns if 'taker' in col] # taker 관련 피처

# 피처 엔지니어링
baseline_extra_columns = ['liquidation_diff', 'liquidation_usd_diff', 'volume_diff', 'liquidation_diffg', 'liquidation_usd_diffg', 'volume_diffg', 'buy_sell_volume_ratio'] # 게시글에 있는 베이스라인 코드의 피처
date_columns = ['ID', 'year', 'month', 'week', 'day_of_week', 'hour']
open_interest_diff_columns = [col for col in df.columns if '_diff' in col]
open_interest_pct_columns =[col for col in df.columns if '_pct_change' in col]
domain_related_columns = ['long_short_ratio', 'liquidation_to_volume_ratio', 'liquidation_usd_ratio', 'funding_rate_position_change', 'premium_diff', 'hashrate_to_difficulty', 'supply_change_rate']
rolling_columns = [col for col in df.columns if 'rolling' in col] # rolling 관련 피처
wt_columns = [col for col in df.columns if 'WT' in col] # WT 관련 피처
ema_columns = [col for col in df.columns if col.endswith('_moving_avg_7')] # WT 관련 피처
shift_7_columns = [series.name for series in shift_list] # shift list 피처 

# category, continuous 열을 따로 할당해둠
category_cols: List[str] = ["liquidation_diffg", "liquidation_usd_diffg", "volume_diffg"]
conti_cols: List[str] = [col for col in df.columns if col not in category_cols + date_columns + rolling_columns + ['target','_type']] # category_cols, date_columns, rolling_columns 에 있는 것들을 제외

# %% [markdown]
# #### lightGBM 학습

# %%
train_df.shape
# Out:
# (8760, 2050)

# %%
# train_test_split 으로 valid set, train set 분리
x_train, x_valid, y_train, y_valid = train_test_split(
    train_df.drop(["target", "ID"], axis = 1), 
    train_df["target"].astype(int), 
    test_size=0.2,
    random_state=42,
)

# 클래스 가중치를 샘플 가중치로 변환
class_weights = {0: 2.5, 1: 0.625, 2: 0.625, 3: 2.5}
sample_weights = np.array([class_weights[label] for label in y_train])

# lgb dataset
train_data = lgb.Dataset(x_train, label=y_train, weight=sample_weights)
valid_data = lgb.Dataset(x_valid, label=y_valid, reference=train_data)

# lgb params (베이스라인 코드의 기본 파라미터임)
params = {
    "boosting_type": "gbdt",
    "objective": "multiclass",
    "metric": "multi_logloss",
    "num_class": 4,
    "num_leaves": 50,
    "learning_rate": 0.05,
    "n_estimators": 30,
    "random_state": 42,
    "verbose": 0,
}

# lgb train
lgb_model = lgb.train(
    params=params,
    train_set=train_data,
    valid_sets=valid_data,
)

# lgb predict
y_valid_pred = lgb_model.predict(x_valid)
y_valid_pred_class = np.argmax(y_valid_pred, axis = 1)

# score check
accuracy = accuracy_score(y_valid, y_valid_pred_class)
auroc = roc_auc_score(y_valid, y_valid_pred, multi_class="ovr")

print(f"acc: {accuracy}, auroc: {auroc}")

# 추가된 confusion matrix 구현 부분
evaluate_model(y_valid, y_valid_pred_class, "lgb_model")
# Out:
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# acc: 0.4195205479452055, auroc: 0.6433989352820748
#
# lgb_model 모델 평가
#
# 분류 보고서:
#               precision    recall  f1-score   support
#
#      Class 0       0.19      0.16      0.17       149
#      Class 1       0.44      0.49      0.46       678
#      Class 2       0.48      0.45      0.46       745
#      Class 3       0.27      0.25      0.26       180
#
#     accuracy                           0.42      1752
#    macro avg       0.34      0.34      0.34      1752
# weighted avg       0.42      0.42      0.42      1752
#
# 혼동 행렬:

# %% [markdown]
# # Feature importance 부분

# %%
# 모델 학습 후 특성 중요도 확인
feature_importance = lgb_model.feature_importance(importance_type='gain')
feature_names = lgb_model.feature_name()

# 특성 중요도를 데이터프레임으로 변환하고 정렬
import pandas as pd
feature_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importance
}).sort_values('importance', ascending=False)

print(feature_importance_df)

# 상위 30개 특성의 중요도를 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(feature_importance_df['feature'][:30], feature_importance_df['importance'][:30])
plt.xticks(rotation=90)
plt.title('Top 20 Feature Importance')
plt.tight_layout()
plt.show()
# Out:
#                                                 feature   importance
# 1110  open-interest_huobi_global_all_symbol_open_int...  1665.066707
# 1064    open-interest_binance_btc_usdt_open_interest_WT  1020.755099
# 10        taker-buy-sell-stats_binance_taker_buy_volume   917.593097
# 1138    taker-buy-sell-stats_bitmex_taker_sell_ratio_WT   808.453813
# 967   taker-buy-sell-stats_bitmex_taker_sell_volume_...   769.838658
# ...                                                 ...          ...
# 853                        premium_diff_rolling_mean_6h     0.000000
# 819   open-interest_bybit_btc_usdt_open_interest_pct...     0.000000
# 809   open-interest_deribit_all_symbol_open_interest...     0.000000
# 810   open-interest_deribit_all_symbol_open_interest...     0.000000
# 351   open-interest_deribit_btc_usd_open_interest_ro...     0.000000
#
# [2048 rows x 2 columns]

# %%
# gain importance 기준으로 오름차순 정렬
feature_importance_df_sorted = feature_importance_df.sort_values('importance', ascending=True)

# 하위 n개 선택
n = 500
bottom = feature_importance_df_sorted.head(n)

# 결과 출력 (모든 행 표시)
print(f"하위 {n}개 특성:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(bottom)
# Out:
# 하위 500개 특성:
#                                                 feature  importance
# 62                       velocity_velocity_supply_total         0.0
# 1985  open-interest_deribit_all_symbol_open_interest...         0.0
# 1986  open-interest_deribit_all_symbol_open_interest...         0.0
# 1987  open-interest_deribit_all_symbol_open_interest...         0.0
# 58    liquidations_huobi_global_all_symbol_short_liq...         0.0
# 1908      open-interest_binance_btc_usd_open_interest_1         0.0
# 521   fees-transaction_fees_transaction_median_usd_r...         0.0
# 509   fees-transaction_fees_transaction_mean_rolling...         0.0
# 511   fees-transaction_fees_transaction_mean_rolling...         0.0
# 513   fees-transaction_fees_transaction_mean_usd_rol...         0.0
# 1881  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1984  open-interest_deribit_all_symbol_open_interest...         0.0
# 63        open-interest_bitmex_all_symbol_open_interest         0.0
# 1905                            utxo-count_utxo_count_5         0.0
# 1876  liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1877  liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1878  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1879  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 116   taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 98           open-interest_bybit_btc_usdt_open_interest         0.0
# 100   open-interest_htx_global_all_symbol_open_interest         0.0
# 105    taker-buy-sell-stats_bitmex_taker_buy_sell_ratio         0.0
# 2041                          hashrate_to_difficulty_23         0.0
# 1200                                    premium_diff_WT         0.0
# 1173                           difficulty_difficulty_WT         0.0
# 1174                           utxo-count_utxo_count_WT         0.0
# 44                                  supply_supply_total         0.0
# 31                  funding-rates_deribit_funding_rates         0.0
# 14    taker-buy-sell-stats_binance_taker_buy_sell_ratio         0.0
# 19     open-interest_huobi_global_btc_usd_open_interest         0.0
# 1140  liquidations_bybit_all_symbol_long_liquidation...         0.0
# 2039                           hashrate_to_difficulty_2         0.0
# 2040                           hashrate_to_difficulty_5         0.0
# 1882  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 2042                          hashrate_to_difficulty_47         0.0
# 2033                                     premium_diff_1         0.0
# 2034                                     premium_diff_2         0.0
# 24     taker-buy-sell-stats_htx_global_taker_sell_ratio         0.0
# 45                                    supply_supply_new         0.0
# 54        taker-buy-sell-stats_okx_taker_buy_sell_ratio         0.0
# 407   liquidations_huobi_global_all_symbol_long_liqu...         0.0
# 1929                                      volume_diff_2         0.0
# 9     taker-buy-sell-stats_all_exchange_taker_buy_se...         0.0
# 634   taker-buy-sell-stats_huobi_global_taker_buy_ra...         0.0
# 652   funding-rates_htx_global_funding_rates_rolling...         0.0
# 1728  taker-buy-sell-stats_bitmex_taker_buy_sell_rat...         0.0
# 1742  liquidations_bybit_all_symbol_long_liquidation...         0.0
# 653   open-interest_bitfinex_all_symbol_open_interes...         0.0
# 654   open-interest_bitfinex_all_symbol_open_interes...         0.0
# 1739  liquidations_bybit_all_symbol_long_liquidation...         0.0
# 630   taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 1680   liquidations_okx_all_symbol_short_liquidations_5         0.0
# 631   taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 632   taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 1729  taker-buy-sell-stats_bitmex_taker_buy_sell_rat...         0.0
# 679   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 127   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1898                            difficulty_difficulty_1         0.0
# 1899                            difficulty_difficulty_2         0.0
# 1900                            difficulty_difficulty_5         0.0
# 1901                           difficulty_difficulty_23         0.0
# 118              funding-rates_htx_global_funding_rates         0.0
# 119     open-interest_bitfinex_all_symbol_open_interest         0.0
# 1913       open-interest_okx_all_symbol_open_interest_1         0.0
# 430   open-interest_bitmex_all_symbol_open_interest_...         0.0
# 1885   open-interest_gate_io_all_symbol_open_interest_5         0.0
# 493   tokens-transferred_tokens_transferred_total_ro...         0.0
# 537   open-interest_gate_io_btc_usdt_open_interest_r...         0.0
# 538   open-interest_gate_io_btc_usdt_open_interest_r...         0.0
# 110      open-interest_deribit_all_symbol_open_interest         0.0
# 112   taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 113   taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 115   taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 122   liquidations_binance_all_symbol_long_liquidati...         0.0
# 125   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1199                    funding_rate_position_change_WT         0.0
# 486   funding-rates_binance_funding_rates_rolling_me...         0.0
# 487   funding-rates_binance_funding_rates_rolling_me...         0.0
# 547   open-interest_gate_io_btc_usd_open_interest_ro...         0.0
# 677   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 678   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 635   taker-buy-sell-stats_huobi_global_taker_buy_ra...         0.0
# 665   liquidations_binance_all_symbol_long_liquidati...         0.0
# 1731  taker-buy-sell-stats_bitmex_taker_buy_sell_rat...         0.0
# 668   liquidations_binance_all_symbol_long_liquidati...         0.0
# 1780  taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 355                supply_supply_total_rolling_mean_24h         0.0
# 356                supply_supply_total_rolling_mean_48h         0.0
# 357                   supply_supply_new_rolling_mean_6h         0.0
# 358                  supply_supply_new_rolling_mean_12h         0.0
# 376   open-interest_kraken_btc_usd_open_interest_rol...         0.0
# 1800  open-interest_bitfinex_all_symbol_open_interest_5         0.0
# 360                  supply_supply_new_rolling_mean_48h         0.0
# 368   addresses-count_addresses_count_sender_rolling...         0.0
# 1778  taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 1779  taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 354                supply_supply_total_rolling_mean_12h         0.0
# 1782  taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 1783  taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 371   addresses-count_addresses_count_receiver_rolli...         0.0
# 373   open-interest_kraken_btc_usd_open_interest_rol...         0.0
# 1798  open-interest_bitfinex_all_symbol_open_interest_1         0.0
# 1799  open-interest_bitfinex_all_symbol_open_interest_2         0.0
# 378   taker-buy-sell-stats_okx_taker_buy_volume_roll...         0.0
# 1843  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1844  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 549   open-interest_bybit_all_symbol_open_interest_r...         0.0
# 810   open-interest_deribit_all_symbol_open_interest...         0.0
# 1832  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 568   liquidations_okx_all_symbol_short_liquidations...         0.0
# 571   open-interest_bybit_btc_usdt_open_interest_rol...         0.0
# 572   open-interest_bybit_btc_usdt_open_interest_rol...         0.0
# 1834  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1835  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1836  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1842  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1838  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1845  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 550   open-interest_bybit_all_symbol_open_interest_r...         0.0
# 551   open-interest_bybit_all_symbol_open_interest_r...         0.0
# 1840  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1841  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1859                          block-count_block_count_2         0.0
# 1776  taker-buy-sell-stats_huobi_global_taker_buy_ra...         0.0
# 1761       open-interest_bybit_btc_usd_open_interest_23         0.0
# 575   open-interest_all_exchange_all_symbol_open_int...         0.0
# 353                 supply_supply_total_rolling_mean_6h         0.0
# 1866  liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1870  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1871  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1872  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1873  liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1858                          block-count_block_count_1         0.0
# 1875  liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1860                          block-count_block_count_5         0.0
# 1833  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1818  liquidations_binance_all_symbol_short_liquidat...         0.0
# 1822  liquidations_binance_all_symbol_short_liquidat...         0.0
# 1869  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1867  liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1868  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1839  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1177                                liquidation_diff_WT         0.0
# 1178                            liquidation_usd_diff_WT         0.0
# 1179                                     volume_diff_WT         0.0
# 1180                           buy_sell_volume_ratio_WT         0.0
# 2035                                     premium_diff_5         0.0
# 1191  open-interest_bybit_btc_usdt_open_interest_pct...         0.0
# 414   liquidations_huobi_global_all_symbol_long_liqu...         0.0
# 1846  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1861                         block-count_block_count_23         0.0
# 1862                         block-count_block_count_47         0.0
# 1176      open-interest_okx_all_symbol_open_interest_WT         0.0
# 397   open-interest_huobi_global_btc_usdt_open_inter...         0.0
# 401   funding-rates_all_exchange_funding_rates_rolli...         0.0
# 402   funding-rates_all_exchange_funding_rates_rolli...         0.0
# 403   funding-rates_all_exchange_funding_rates_rolli...         0.0
# 428     velocity_velocity_supply_total_rolling_mean_48h         0.0
# 429   open-interest_bitmex_all_symbol_open_interest_...         0.0
# 1902                           difficulty_difficulty_47         0.0
# 421   open-interest_okx_btc_usdt_open_interest_rolli...         0.0
# 422   open-interest_okx_btc_usdt_open_interest_rolli...         0.0
# 4       taker-buy-sell-stats_bybit_taker_buy_sell_ratio         0.0
# 1175     open-interest_binance_btc_usd_open_interest_WT         0.0
# 408   liquidations_huobi_global_all_symbol_long_liqu...         0.0
# 1785  taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 1786  taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 1787  taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 1790               funding-rates_bitmex_funding_rates_5         0.0
# 339                    fees_fees_total_rolling_mean_24h         0.0
# 343                fees_fees_total_usd_rolling_mean_24h         0.0
# 344                fees_fees_total_usd_rolling_mean_48h         0.0
# 1474    taker-buy-sell-stats_okx_taker_buy_sell_ratio_2         0.0
# 346           fees_fees_reward_percent_rolling_mean_12h         0.0
# 347           fees_fees_reward_percent_rolling_mean_24h         0.0
# 854                       premium_diff_rolling_mean_12h         0.0
# 856                       premium_diff_rolling_mean_48h         0.0
# 349   open-interest_deribit_btc_usd_open_interest_ro...         0.0
# 811   open-interest_deribit_all_symbol_open_interest...         0.0
# 1424                              supply_supply_total_2         0.0
# 342                fees_fees_total_usd_rolling_mean_12h         0.0
# 692   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 691   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 858             hashrate_to_difficulty_rolling_mean_12h         0.0
# 859             hashrate_to_difficulty_rolling_mean_24h         0.0
# 860             hashrate_to_difficulty_rolling_mean_48h         0.0
# 853                        premium_diff_rolling_mean_6h         0.0
# 819   open-interest_bybit_btc_usdt_open_interest_pct...         0.0
# 345            fees_fees_reward_percent_rolling_mean_6h         0.0
# 705   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1389   open-interest_htx_global_btc_usd_open_interest_2         0.0
# 151                                               month         0.0
# 1795           funding-rates_htx_global_funding_rates_5         0.0
# 656   open-interest_bitfinex_all_symbol_open_interes...         0.0
# 690   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 685   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1625       fees-transaction_fees_transaction_mean_usd_5         0.0
# 1775  taker-buy-sell-stats_huobi_global_taker_buy_ra...         0.0
# 1626      fees-transaction_fees_transaction_mean_usd_23         0.0
# 1774  taker-buy-sell-stats_huobi_global_taker_buy_ra...         0.0
# 1773  taker-buy-sell-stats_huobi_global_taker_buy_ra...         0.0
# 1771  taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 1390   open-interest_htx_global_btc_usd_open_interest_5         0.0
# 152                                                week         0.0
# 693   open-interest_binance_all_symbol_open_interest...         0.0
# 694   open-interest_binance_all_symbol_open_interest...         0.0
# 1769  taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 680   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 325   open-interest_htx_global_btc_usd_open_interest...         0.0
# 328   open-interest_htx_global_btc_usd_open_interest...         0.0
# 218   taker-buy-sell-stats_binance_taker_buy_volume_...         0.0
# 341                 fees_fees_total_usd_rolling_mean_6h         0.0
# 1578  liquidations_huobi_global_btc_usdt_short_liqui...         0.0
# 733               difficulty_difficulty_rolling_mean_6h         0.0
# 734              difficulty_difficulty_rolling_mean_12h         0.0
# 706   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 709   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 710   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1427                             supply_supply_total_47         0.0
# 697   open-interest_htx_global_btc_usdt_open_interes...         0.0
# 698   open-interest_htx_global_btc_usdt_open_interes...         0.0
# 699   open-interest_htx_global_btc_usdt_open_interes...         0.0
# 700   open-interest_htx_global_btc_usdt_open_interes...         0.0
# 732        blockreward_blockreward_usd_rolling_mean_48h         0.0
# 651   funding-rates_htx_global_funding_rates_rolling...         0.0
# 704            block-count_block_count_rolling_mean_48h         0.0
# 926   open-interest_okx_btc_usdt_open_interest_movin...         0.0
# 1432                               supply_supply_new_47         0.0
# 1417                        fees_fees_reward_percent_47         0.0
# 1418      open-interest_deribit_btc_usd_open_interest_1         0.0
# 1420      open-interest_deribit_btc_usd_open_interest_5         0.0
# 1428                                supply_supply_new_1         0.0
# 809   open-interest_deribit_all_symbol_open_interest...         0.0
# 672   liquidations_binance_all_symbol_short_liquidat...         0.0
# 1653     open-interest_gate_io_btc_usdt_open_interest_1         0.0
# 1655     open-interest_gate_io_btc_usdt_open_interest_5         0.0
# 1509         open-interest_okx_btc_usdt_open_interest_2         0.0
# 139                               difficulty_difficulty         0.0
# 145                                         volume_diff         0.0
# 146                                   liquidation_diffg         0.0
# 147                               liquidation_usd_diffg         0.0
# 148                                        volume_diffg         0.0
# 619   open-interest_deribit_all_symbol_open_interest...         0.0
# 670   liquidations_binance_all_symbol_short_liquidat...         0.0
# 1796          funding-rates_htx_global_funding_rates_23         0.0
# 132   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 720   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 721   open-interest_gate_io_all_symbol_open_interest...         0.0
# 724   open-interest_gate_io_all_symbol_open_interest...         0.0
# 712   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 713   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 42                             fees_fees_reward_percent         0.0
# 742   open-interest_binance_btc_usd_open_interest_ro...         0.0
# 745   open-interest_okx_all_symbol_open_interest_rol...         0.0
# 616   coinbase-premium-index_coinbase_premium_index_...         0.0
# 1693       open-interest_bybit_btc_usdt_open_interest_1         0.0
# 629   taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 649   funding-rates_htx_global_funding_rates_rolling...         0.0
# 1794           funding-rates_htx_global_funding_rates_2         0.0
# 1793           funding-rates_htx_global_funding_rates_1         0.0
# 1807  liquidations_binance_all_symbol_long_liquidati...         0.0
# 1805  liquidations_binance_all_symbol_long_liquidati...         0.0
# 1804  liquidations_binance_all_symbol_long_liquidati...         0.0
# 617   open-interest_deribit_all_symbol_open_interest...         0.0
# 150                                                year         0.0
# 1705  open-interest_htx_global_all_symbol_open_inter...         0.0
# 613   coinbase-premium-index_coinbase_premium_index_...         0.0
# 612   coinbase-premium-index_coinbase_premium_gap_ro...         0.0
# 626   taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 625   taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 681   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 578   open-interest_htx_global_all_symbol_open_inter...         0.0
# 689   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 683   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1754   open-interest_deribit_all_symbol_open_interest_2         0.0
# 577   open-interest_htx_global_all_symbol_open_inter...         0.0
# 1904                            utxo-count_utxo_count_2         0.0
# 686   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1906                           utxo-count_utxo_count_23         0.0
# 1907                           utxo-count_utxo_count_47         0.0
# 1706  open-interest_htx_global_all_symbol_open_inter...         0.0
# 628   taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 650   funding-rates_htx_global_funding_rates_rolling...         0.0
# 1735  liquidations_bybit_all_symbol_long_liquidations_5         0.0
# 1681  liquidations_okx_all_symbol_short_liquidations_23         0.0
# 1732  taker-buy-sell-stats_bitmex_taker_buy_sell_rat...         0.0
# 1753   open-interest_deribit_all_symbol_open_interest_1         0.0
# 576   open-interest_all_exchange_all_symbol_open_int...         0.0
# 1682  liquidations_okx_all_symbol_short_liquidations_47         0.0
# 1675    liquidations_okx_all_symbol_long_liquidations_5         0.0
# 579   open-interest_htx_global_all_symbol_open_inter...         0.0
# 580   open-interest_htx_global_all_symbol_open_inter...         0.0
# 1701  open-interest_all_exchange_all_symbol_open_int...         0.0
# 610   coinbase-premium-index_coinbase_premium_gap_ro...         0.0
# 1703  open-interest_htx_global_all_symbol_open_inter...         0.0
# 1704  open-interest_htx_global_all_symbol_open_inter...         0.0
# 1669     open-interest_bybit_all_symbol_open_interest_2         0.0
# 606   liquidations_bybit_all_symbol_long_liquidation...         0.0
# 642   taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 643   taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 574   open-interest_all_exchange_all_symbol_open_int...         0.0
# 1707  open-interest_htx_global_all_symbol_open_inter...         0.0
# 1749    coinbase-premium-index_coinbase_premium_index_2         0.0
# 1699  open-interest_all_exchange_all_symbol_open_int...         0.0
# 1656    open-interest_gate_io_btc_usdt_open_interest_23         0.0
# 1635     fees-transaction_fees_transaction_median_usd_5         0.0
# 1643         funding-rates_huobi_global_funding_rates_1         0.0
# 641   taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 1670     open-interest_bybit_all_symbol_open_interest_5         0.0
# 1671    open-interest_bybit_all_symbol_open_interest_23         0.0
# 1657    open-interest_gate_io_btc_usdt_open_interest_47         0.0
# 1757  open-interest_deribit_all_symbol_open_interest_47         0.0
# 1663      open-interest_gate_io_btc_usd_open_interest_1         0.0
# 655   open-interest_bitfinex_all_symbol_open_interes...         0.0
# 1756  open-interest_deribit_all_symbol_open_interest_23         0.0
# 1755   open-interest_deribit_all_symbol_open_interest_5         0.0
# 1797          funding-rates_htx_global_funding_rates_47         0.0
# 1802  open-interest_bitfinex_all_symbol_open_interes...         0.0
# 684   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1768  taker-buy-sell-stats_huobi_global_taker_sell_v...         0.0
# 701             block-count_block_count_rolling_mean_6h         0.0
# 1767  taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 1765  taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 1764  taker-buy-sell-stats_huobi_global_taker_buy_vo...         0.0
# 702            block-count_block_count_rolling_mean_12h         0.0
# 703            block-count_block_count_rolling_mean_24h         0.0
# 688   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 644   taker-buy-sell-stats_huobi_global_taker_buy_se...         0.0
# 1831  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1801  open-interest_bitfinex_all_symbol_open_interes...         0.0
# 682   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 620   open-interest_deribit_all_symbol_open_interest...         0.0
# 621   open-interest_bybit_btc_usd_open_interest_roll...         0.0
# 622   open-interest_bybit_btc_usd_open_interest_roll...         0.0
# 638   taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 618   open-interest_deribit_all_symbol_open_interest...         0.0
# 639   taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 640   taker-buy-sell-stats_huobi_global_taker_sell_r...         0.0
# 717   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 770                       volume_diffg_rolling_mean_12h         0.0
# 1552   open-interest_kraken_all_symbol_open_interest_47         0.0
# 1548    open-interest_kraken_all_symbol_open_interest_1         0.0
# 1549    open-interest_kraken_all_symbol_open_interest_2         0.0
# 1388   open-interest_htx_global_btc_usd_open_interest_1         0.0
# 191   taker-buy-sell-stats_bybit_taker_sell_ratio_ro...         0.0
# 131                             block-count_block_count         0.0
# 714   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 715   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 716   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 769                        volume_diffg_rolling_mean_6h         0.0
# 718   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1564  liquidations_huobi_global_btc_usdt_long_liquid...         0.0
# 1569  liquidations_huobi_global_btc_usdt_short_liqui...         0.0
# 1551   open-interest_kraken_all_symbol_open_interest_23         0.0
# 736              difficulty_difficulty_rolling_mean_48h         0.0
# 1550    open-interest_kraken_all_symbol_open_interest_5         0.0
# 327   open-interest_htx_global_btc_usd_open_interest...         0.0
# 1518    open-interest_bitmex_all_symbol_open_interest_1         0.0
# 1519    open-interest_bitmex_all_symbol_open_interest_2         0.0
# 1520    open-interest_bitmex_all_symbol_open_interest_5         0.0
# 134   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1595          open-interest_okx_btc_usd_open_interest_5         0.0
# 128   liquidations_htx_global_all_symbol_short_liqui...         0.0
# 130     open-interest_htx_global_btc_usdt_open_interest         0.0
# 1581  liquidations_huobi_global_btc_usdt_short_liqui...         0.0
# 1583  open-interest_huobi_global_all_symbol_open_int...         0.0
# 1589              funding-rates_binance_funding_rates_2         0.0
# 1572  liquidations_huobi_global_btc_usdt_short_liqui...         0.0
# 1574  liquidations_huobi_global_btc_usdt_long_liquid...         0.0
# 737               utxo-count_utxo_count_rolling_mean_6h         0.0
# 133   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1521   open-interest_bitmex_all_symbol_open_interest_23         0.0
# 1117          fees-transaction_fees_transaction_mean_WT         0.0
# 1118      fees-transaction_fees_transaction_mean_usd_WT         0.0
# 1253    taker-buy-sell-stats_binance_taker_buy_volume_1         0.0
# 1120    fees-transaction_fees_transaction_median_usd_WT         0.0
# 815   open-interest_deribit_all_symbol_open_interest...         0.0
# 719   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 765               liquidation_usd_diffg_rolling_mean_6h         0.0
# 767              liquidation_usd_diffg_rolling_mean_24h         0.0
# 768              liquidation_usd_diffg_rolling_mean_48h         0.0
# 1116                               hashrate_hashrate_WT         0.0
# 1170  open-interest_gate_io_all_symbol_open_interest_WT         0.0
# 1172                     blockreward_blockreward_usd_WT         0.0
# 1245  taker-buy-sell-stats_all_exchange_taker_sell_r...         0.0
# 1123                         block-bytes_block_bytes_WT         0.0
# 1106  liquidations_huobi_global_btc_usdt_long_liquid...         0.0
# 1107  liquidations_huobi_global_btc_usdt_short_liqui...         0.0
# 1108  liquidations_huobi_global_btc_usdt_long_liquid...         0.0
# 1114      tokens-transferred_tokens_transferred_mean_WT         0.0
# 1115    tokens-transferred_tokens_transferred_median_WT         0.0
# 1130  liquidations_okx_all_symbol_long_liquidations_...         0.0
# 1169  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 1981  open-interest_deribit_all_symbol_open_interest...         0.0
# 1982  open-interest_deribit_all_symbol_open_interest...         0.0
# 1983  open-interest_deribit_all_symbol_open_interest...         0.0
# 33         liquidations_okx_btc_usdt_short_liquidations         0.0
# 95       liquidations_okx_all_symbol_short_liquidations         0.0
# 86         fees-transaction_fees_transaction_median_usd         0.0
# 88             funding-rates_huobi_global_funding_rates         0.0
# 92          open-interest_gate_io_btc_usd_open_interest         0.0
# 1830  liquidations_htx_global_all_symbol_long_liquid...         0.0
# 1225  taker-buy-sell-stats_bybit_taker_buy_sell_ratio_5         0.0
# 1252  taker-buy-sell-stats_all_exchange_taker_buy_se...         0.0
# 1275  taker-buy-sell-stats_binance_taker_buy_sell_ra...         0.0
# 1276  taker-buy-sell-stats_binance_taker_buy_sell_ra...         0.0
# 1254    taker-buy-sell-stats_binance_taker_buy_volume_2         0.0
# 1256   taker-buy-sell-stats_binance_taker_buy_volume_23         0.0
# 994   open-interest_binance_all_symbol_open_interest...         0.0
# 1054      open-interest_bitmex_btc_usd_open_interest_WT         0.0
# 1055  taker-buy-sell-stats_htx_global_taker_buy_volu...         0.0
# 1056  taker-buy-sell-stats_htx_global_taker_sell_vol...         0.0
# 1063  liquidations_binance_btc_usdt_short_liquidatio...         0.0
# 708   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1251  taker-buy-sell-stats_all_exchange_taker_buy_se...         0.0
# 1162  liquidations_htx_global_all_symbol_short_liqui...         0.0
# 1164  open-interest_htx_global_btc_usdt_open_interes...         0.0
# 1152          funding-rates_htx_global_funding_rates_WT         0.0
# 274   taker-buy-sell-stats_htx_global_taker_sell_rat...         0.0
# 258   open-interest_bitmex_btc_usd_open_interest_rol...         0.0
# 259   open-interest_bitmex_btc_usd_open_interest_rol...         0.0
# 1105      transactions-count_transactions_count_mean_WT         0.0
# 1167  liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 711   liquidations_htx_global_btc_usdt_short_liquida...         0.0
# 203   taker-buy-sell-stats_all_exchange_taker_sell_v...         0.0
# 204   taker-buy-sell-stats_all_exchange_taker_sell_v...         0.0
# 1503  liquidations_huobi_global_all_symbol_short_liq...         0.0
# 348           fees_fees_reward_percent_rolling_mean_48h         0.0
# 333            fees_fees_block_mean_usd_rolling_mean_6h         0.0
# 335           fees_fees_block_mean_usd_rolling_mean_24h         0.0
# 336           fees_fees_block_mean_usd_rolling_mean_48h         0.0
# 1400                         fees_fees_block_mean_usd_5         0.0
# 1492  liquidations_huobi_global_all_symbol_long_liqu...         0.0
# 816   open-interest_deribit_all_symbol_open_interest...         0.0
# 1391  open-interest_htx_global_btc_usd_open_interest_23         0.0
# 1401                        fees_fees_block_mean_usd_23         0.0
# 1392  open-interest_htx_global_btc_usd_open_interest_47         0.0
# 1399                         fees_fees_block_mean_usd_2         0.0
# 934   open-interest_kraken_all_symbol_open_interest_...         0.0
# 927         velocity_velocity_supply_total_moving_avg_7         0.0
# 928   open-interest_bitmex_all_symbol_open_interest_...         0.0
# 914   open-interest_kraken_btc_usd_open_interest_mov...         0.0
# 920   open-interest_huobi_global_btc_usdt_open_inter...         0.0
# 1413                         fees_fees_reward_percent_1         0.0
# 902   open-interest_htx_global_btc_usd_open_interest...         0.0
# 326   open-interest_htx_global_btc_usd_open_interest...         0.0
# 1431                               supply_supply_new_23         0.0
# 895   open-interest_binance_btc_usdt_open_interest_m...         0.0
# 885   open-interest_bitmex_btc_usd_open_interest_mov...         0.0
# 351   open-interest_deribit_btc_usd_open_interest_ro...         0.0
# 735              difficulty_difficulty_rolling_mean_24h         0.0
# 937   liquidations_huobi_global_btc_usdt_long_liquid...         0.0
# 909                    supply_supply_total_moving_avg_7         0.0
# 900   liquidations_okx_btc_usdt_short_liquidations_u...         0.0
# 901   open-interest_bitfinex_btc_usdt_open_interest_...         0.0
# 1414                         fees_fees_reward_percent_2         0.0
# 903                   fees_fees_block_mean_moving_avg_7         0.0
# 1423                              supply_supply_total_1         0.0
# 1425                              supply_supply_total_5         0.0
# 1426                             supply_supply_total_23         0.0
# 904               fees_fees_block_mean_usd_moving_avg_7         0.0
# 906                    fees_fees_total_usd_moving_avg_7         0.0
# 907               fees_fees_reward_percent_moving_avg_7         0.0
# 908   open-interest_deribit_btc_usd_open_interest_mo...         0.0
# 1416                        fees_fees_reward_percent_23         0.0
# 1516                  velocity_velocity_supply_total_23         0.0
# 1522   open-interest_bitmex_all_symbol_open_interest_47         0.0
# 687   liquidations_htx_global_all_symbol_long_liquid...         0.0
# 738              utxo-count_utxo_count_rolling_mean_12h         0.0
# 739              utxo-count_utxo_count_rolling_mean_24h         0.0
# 746   open-interest_okx_all_symbol_open_interest_rol...         0.0
# 183   taker-buy-sell-stats_bybit_taker_sell_volume_r...         0.0
# 761                   liquidation_diffg_rolling_mean_6h         0.0
# 174                                        premium_diff         0.0
# 175                              hashrate_to_difficulty         0.0
# 163   open-interest_deribit_all_symbol_open_interest...         0.0
# 323   open-interest_bitfinex_btc_usdt_open_interest_...         0.0
# 1517                  velocity_velocity_supply_total_47         0.0
# 771                       volume_diffg_rolling_mean_24h         0.0
# 772                       volume_diffg_rolling_mean_48h         0.0
# 757                         volume_diff_rolling_mean_6h         0.0
# 758                        volume_diff_rolling_mean_12h         0.0
# 759                        volume_diff_rolling_mean_24h         0.0
# 760                        volume_diff_rolling_mean_48h         0.0
# 164   open-interest_deribit_all_symbol_open_interest...         0.0
# 707   liquidations_htx_global_btc_usdt_long_liquidat...         0.0
# 1513                   velocity_velocity_supply_total_1         0.0
# 1415                         fees_fees_reward_percent_5         0.0
# 955   open-interest_gate_io_btc_usdt_open_interest_m...         0.0
# 940   liquidations_huobi_global_btc_usdt_short_liqui...         0.0
# 943   open-interest_okx_btc_usd_open_interest_moving...         0.0
# 948   fees-transaction_fees_transaction_mean_moving_...         0.0
# 1384    open-interest_bitfinex_btc_usdt_open_interest_2         0.0
# 812   open-interest_deribit_all_symbol_open_interest...         0.0
# 813   open-interest_deribit_all_symbol_open_interest...         0.0
# 814   open-interest_deribit_all_symbol_open_interest...         0.0
# 1510         open-interest_okx_btc_usdt_open_interest_5         0.0
# 453   open-interest_kraken_all_symbol_open_interest_...         0.0
# 1514                   velocity_velocity_supply_total_2         0.0
# 1515                   velocity_velocity_supply_total_5         0.0

# %%
# gain importance 기준으로 내림차순 정렬
feature_importance_df_sorted = feature_importance_df.sort_values('importance', ascending=False)

# 상위 n개 선택
n = 500
bottom = feature_importance_df_sorted.head(n)

# 결과 출력 (모든 행 표시)
print(f"상위 {n}개 특성:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(bottom)
# Out:
# 상위 500개 특성:
#                                                 feature   importance
# 1110  open-interest_huobi_global_all_symbol_open_int...  1665.066707
# 1064    open-interest_binance_btc_usdt_open_interest_WT  1020.755099
# 10        taker-buy-sell-stats_binance_taker_buy_volume   917.593097
# 1138    taker-buy-sell-stats_bitmex_taker_sell_ratio_WT   808.453813
# 967   taker-buy-sell-stats_bitmex_taker_sell_volume_...   769.838658
# 102       taker-buy-sell-stats_bitmex_taker_sell_volume   734.055897
# 123   liquidations_binance_all_symbol_short_liquidat...   712.913008
# 865   taker-buy-sell-stats_bybit_taker_buy_volume_mo...   644.893067
# 586   taker-buy-sell-stats_bitmex_taker_sell_volume_...   619.819599
# 0           taker-buy-sell-stats_bybit_taker_buy_volume   492.223682
# 916   taker-buy-sell-stats_okx_taker_sell_volume_mov...   457.325008
# 1          taker-buy-sell-stats_bybit_taker_sell_volume   425.507067
# 1602     tokens-transferred_tokens_transferred_total_47   423.881918
# 1989  open-interest_bybit_btc_usdt_open_interest_pct...   417.650936
# 64        taker-buy-sell-stats_deribit_taker_buy_volume   360.325171
# 168   open-interest_bitfinex_btc_usdt_open_interest_...   354.983653
# 1194  open-interest_bitfinex_btc_usdt_open_interest_...   324.051250
# 1025  open-interest_bitfinex_btc_usdt_open_interest_...   317.177378
# 1192  open-interest_bybit_btc_usdt_open_interest_dif...   305.641100
# 65       taker-buy-sell-stats_deribit_taker_sell_volume   305.545116
# 2001  open-interest_bitfinex_btc_usdt_open_interest_...   302.828458
# 149                               buy_sell_volume_ratio   292.219800
# 1316  taker-buy-sell-stats_htx_global_taker_sell_vol...   271.475793
# 1214       taker-buy-sell-stats_bybit_taker_buy_ratio_2   270.913380
# 1464         taker-buy-sell-stats_okx_taker_buy_ratio_2   258.704852
# 1447        addresses-count_addresses_count_receiver_47   257.434220
# 1994  open-interest_bybit_btc_usdt_open_interest_diff_2   253.840640
# 171                         liquidation_to_volume_ratio   251.261310
# 50            taker-buy-sell-stats_okx_taker_buy_volume   249.516360
# 167   open-interest_bitfinex_btc_usdt_open_interest_...   249.146018
# 1946  open-interest_all_exchange_all_symbol_open_int...   246.930298
# 51           taker-buy-sell-stats_okx_taker_sell_volume   234.101851
# 15    liquidations_all_exchange_all_symbol_long_liqu...   225.446081
# 1069  liquidations_okx_btc_usdt_short_liquidations_u...   224.355303
# 363   addresses-count_addresses_count_active_rolling...   223.562307
# 1089  open-interest_huobi_global_btc_usdt_open_inter...   220.745402
# 2002  open-interest_bitfinex_btc_usdt_open_interest_...   208.409060
# 782   open-interest_all_exchange_all_symbol_open_int...   208.294298
# 1962  open-interest_okx_btc_usdt_open_interest_pct_c...   207.318589
# 87                        block-interval_block_interval   206.371082
# 502   tokens-transferred_tokens_transferred_median_r...   206.064799
# 1639                    block-interval_block_interval_2   205.219280
# 930   taker-buy-sell-stats_deribit_taker_sell_volume...   204.521698
# 322   open-interest_bitfinex_btc_usdt_open_interest_...   203.907701
# 1212    taker-buy-sell-stats_bybit_taker_sell_volume_47   203.894411
# 1611    tokens-transferred_tokens_transferred_median_23   202.637521
# 1937                           buy_sell_volume_ratio_47   202.120103
# 173                        funding_rate_position_change   196.198101
# 1961  open-interest_okx_btc_usdt_open_interest_pct_c...   192.121732
# 1018  open-interest_deribit_btc_usd_open_interest_pc...   190.704209
# 1011                 buy_sell_volume_ratio_moving_avg_7   190.655602
# 156   open-interest_all_exchange_all_symbol_open_int...   187.195052
# 1347  liquidations_binance_btc_usdt_long_liquidation...   187.047298
# 12         taker-buy-sell-stats_binance_taker_buy_ratio   186.129770
# 1587  open-interest_huobi_global_all_symbol_open_int...   184.214955
# 1436          addresses-count_addresses_count_active_23   182.614100
# 1600      tokens-transferred_tokens_transferred_total_5   178.070629
# 1255    taker-buy-sell-stats_binance_taker_buy_volume_5   177.842250
# 52             taker-buy-sell-stats_okx_taker_buy_ratio   177.369762
# 80           tokens-transferred_tokens_transferred_mean   175.158360
# 1205      taker-buy-sell-stats_bybit_taker_buy_volume_5   169.817508
# 157   open-interest_binance_btc_usd_open_interest_pc...   169.301191
# 1650                          block-bytes_block_bytes_5   168.008420
# 400   open-interest_huobi_global_btc_usdt_open_inter...   166.525999
# 1718      taker-buy-sell-stats_bitmex_taker_buy_ratio_1   166.266521
# 1603       tokens-transferred_tokens_transferred_mean_1   166.069248
# 2018                      liquidation_to_volume_ratio_1   165.429191
# 1651                         block-bytes_block_bytes_23   164.336349
# 1537    taker-buy-sell-stats_deribit_taker_buy_ratio_47   162.796269
# 864                 supply_change_rate_rolling_mean_48h   162.019033
# 159   open-interest_okx_btc_usdt_open_interest_pct_c...   161.916620
# 1386   open-interest_bitfinex_btc_usdt_open_interest_23   160.678442
# 443   taker-buy-sell-stats_deribit_taker_buy_ratio_r...   159.650600
# 1463         taker-buy-sell-stats_okx_taker_buy_ratio_1   157.768760
# 1640                    block-interval_block_interval_5   154.271978
# 1973  open-interest_deribit_btc_usd_open_interest_di...   152.433558
# 1562      transactions-count_transactions_count_mean_47   150.286820
# 1617                               hashrate_hashrate_47   148.679151
# 829   open-interest_bitfinex_btc_usdt_open_interest_...   146.457558
# 1710     taker-buy-sell-stats_bitmex_taker_buy_volume_5   145.435801
# 1208     taker-buy-sell-stats_bybit_taker_sell_volume_1   144.881581
# 1972  open-interest_deribit_btc_usd_open_interest_pc...   144.483830
# 1599      tokens-transferred_tokens_transferred_total_2   144.376728
# 1971  open-interest_deribit_btc_usd_open_interest_pc...   142.522320
# 1966   open-interest_okx_btc_usdt_open_interest_diff_23   141.106962
# 1101   taker-buy-sell-stats_deribit_taker_sell_ratio_WT   140.918280
# 1443         addresses-count_addresses_count_receiver_1   140.714561
# 464   transactions-count_transactions_count_mean_rol...   140.094801
# 1472       taker-buy-sell-stats_okx_taker_sell_ratio_47   139.702342
# 1528   taker-buy-sell-stats_deribit_taker_sell_volume_1   139.312429
# 1460       taker-buy-sell-stats_okx_taker_sell_volume_5   138.844702
# 169   open-interest_bybit_all_symbol_open_interest_p...   138.095081
# 138                         blockreward_blockreward_usd   137.458120
# 160       open-interest_okx_btc_usdt_open_interest_diff   137.205878
# 1235  taker-buy-sell-stats_all_exchange_taker_sell_v...   137.062702
# 970   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...   137.023523
# 1597         open-interest_okx_btc_usd_open_interest_47   136.487697
# 1217      taker-buy-sell-stats_bybit_taker_buy_ratio_47   135.091310
# 924   liquidations_huobi_global_all_symbol_long_liqu...   134.867340
# 2031                    funding_rate_position_change_23   134.829010
# 2019                      liquidation_to_volume_ratio_2   134.782559
# 1339  liquidations_binance_btc_usdt_short_liquidatio...   133.866717
# 1319  taker-buy-sell-stats_htx_global_taker_buy_ratio_2   132.176441
# 364   addresses-count_addresses_count_active_rolling...   132.065370
# 144                                liquidation_usd_diff   131.124247
# 1826                 funding-rates_okx_funding_rates_23   130.935599
# 393   taker-buy-sell-stats_okx_taker_buy_sell_ratio_...   129.679231
# 1266    taker-buy-sell-stats_binance_taker_buy_ratio_23   129.479028
# 1893                      blockreward_blockreward_usd_1   128.284619
# 71           transactions-count_transactions_count_mean   128.173491
# 1998  open-interest_bitfinex_btc_usdt_open_interest_...   128.148600
# 755               liquidation_usd_diff_rolling_mean_24h   127.613201
# 1948  open-interest_binance_btc_usd_open_interest_pc...   126.669231
# 23      taker-buy-sell-stats_htx_global_taker_buy_ratio   126.374290
# 725             blockreward_blockreward_rolling_mean_6h   125.894891
# 1314  taker-buy-sell-stats_htx_global_taker_sell_vol...   125.296009
# 1941  open-interest_all_exchange_all_symbol_open_int...   125.127900
# 1964    open-interest_okx_btc_usdt_open_interest_diff_2   124.636229
# 1238  taker-buy-sell-stats_all_exchange_taker_buy_ra...   124.468899
# 1030          funding_rate_position_change_moving_avg_7   123.726169
# 1312  taker-buy-sell-stats_htx_global_taker_buy_volu...   123.708970
# 21     taker-buy-sell-stats_htx_global_taker_buy_volume   123.689160
# 1534     taker-buy-sell-stats_deribit_taker_buy_ratio_2   123.087620
# 1002               blockreward_blockreward_moving_avg_7   122.855140
# 1215       taker-buy-sell-stats_bybit_taker_buy_ratio_5   122.586090
# 1641                   block-interval_block_interval_23   122.348221
# 137                             blockreward_blockreward   121.885359
# 170   open-interest_bybit_all_symbol_open_interest_diff   121.773521
# 1598      tokens-transferred_tokens_transferred_total_1   120.845449
# 179   taker-buy-sell-stats_bybit_taker_buy_volume_ro...   120.688621
# 1958  open-interest_okx_btc_usdt_open_interest_pct_c...   120.050250
# 269   taker-buy-sell-stats_htx_global_taker_buy_rati...   119.574239
# 1446        addresses-count_addresses_count_receiver_23   119.489550
# 843        liquidation_to_volume_ratio_rolling_mean_24h   119.426980
# 177   taker-buy-sell-stats_bybit_taker_buy_volume_ro...   119.395199
# 3           taker-buy-sell-stats_bybit_taker_sell_ratio   119.327798
# 1686  liquidations_okx_all_symbol_long_liquidations_...   119.220160
# 1952  open-interest_binance_btc_usd_open_interest_pc...   119.040411
# 1951  open-interest_binance_btc_usd_open_interest_pc...   118.811690
# 1955  open-interest_binance_btc_usd_open_interest_di...   118.541622
# 2024                            liquidation_usd_ratio_2   118.318790
# 1585  open-interest_huobi_global_all_symbol_open_int...   118.304101
# 785   open-interest_binance_btc_usd_open_interest_pc...   118.254439
# 1614                                hashrate_hashrate_2   117.752429
# 1193  open-interest_bitfinex_btc_usdt_open_interest_...   117.549230
# 666   liquidations_binance_all_symbol_long_liquidati...   117.302390
# 846              liquidation_usd_ratio_rolling_mean_12h   117.001179
# 1026  open-interest_bybit_all_symbol_open_interest_p...   116.477388
# 1977  open-interest_deribit_btc_usd_open_interest_di...   116.350192
# 1713    taker-buy-sell-stats_bitmex_taker_sell_volume_1   116.323001
# 1282  liquidations_all_exchange_all_symbol_long_liqu...   115.983429
# 1586  open-interest_huobi_global_all_symbol_open_int...   115.938398
# 1649                          block-bytes_block_bytes_2   115.796309
# 1349  liquidations_binance_btc_usdt_short_liquidatio...   115.580520
# 362   addresses-count_addresses_count_active_rolling...   115.290760
# 1889                          blockreward_blockreward_2   115.262029
# 66         taker-buy-sell-stats_deribit_taker_buy_ratio   115.224380
# 1556     transactions-count_transactions_count_total_23   115.172750
# 825   open-interest_bitfinex_btc_usdt_open_interest_...   115.009880
# 166     open-interest_bybit_btc_usdt_open_interest_diff   114.943501
# 70          transactions-count_transactions_count_total   114.394140
# 1609     tokens-transferred_tokens_transferred_median_2   114.224500
# 438   taker-buy-sell-stats_deribit_taker_sell_volume...   114.038598
# 818   open-interest_bybit_btc_usdt_open_interest_pct...   113.464269
# 76    open-interest_huobi_global_all_symbol_open_int...   112.961297
# 1999  open-interest_bitfinex_btc_usdt_open_interest_...   112.859840
# 1462      taker-buy-sell-stats_okx_taker_sell_volume_47   112.776400
# 1975  open-interest_deribit_btc_usd_open_interest_di...   111.931639
# 2026                           liquidation_usd_ratio_23   111.874500
# 1561      transactions-count_transactions_count_mean_23   111.574111
# 1326  taker-buy-sell-stats_htx_global_taker_sell_rat...   111.521552
# 1465         taker-buy-sell-stats_okx_taker_buy_ratio_5   110.137850
# 824   open-interest_bybit_btc_usdt_open_interest_dif...   110.006541
# 277   taker-buy-sell-stats_htx_global_taker_buy_sell...   109.940539
# 1991  open-interest_bybit_btc_usdt_open_interest_pct...   109.722659
# 1949  open-interest_binance_btc_usd_open_interest_pc...   109.520500
# 452   taker-buy-sell-stats_deribit_taker_buy_sell_ra...   109.210398
# 1601     tokens-transferred_tokens_transferred_total_23   109.092898
# 1894                      blockreward_blockreward_usd_2   108.796099
# 1012  open-interest_all_exchange_all_symbol_open_int...   108.548179
# 7     taker-buy-sell-stats_all_exchange_taker_buy_ratio   108.397191
# 883   liquidations_all_exchange_all_symbol_short_liq...   107.306789
# 1348  liquidations_binance_btc_usdt_short_liquidatio...   107.197300
# 278   taker-buy-sell-stats_htx_global_taker_buy_sell...   106.947279
# 1405                                  fees_fees_total_5   106.856849
# 1957  open-interest_binance_btc_usd_open_interest_di...   106.467290
# 18    liquidations_all_exchange_all_symbol_short_liq...   106.128597
# 82                                    hashrate_hashrate   105.915150
# 369   addresses-count_addresses_count_receiver_rolli...   105.814281
# 1024  open-interest_bitfinex_btc_usdt_open_interest_...   105.692002
# 1466        taker-buy-sell-stats_okx_taker_buy_ratio_23   105.404971
# 1997  open-interest_bybit_btc_usdt_open_interest_dif...   104.955880
# 1530   taker-buy-sell-stats_deribit_taker_sell_volume_5   104.875359
# 1956  open-interest_binance_btc_usd_open_interest_di...   104.275700
# 528      block-interval_block_interval_rolling_mean_48h   103.663719
# 2012  open-interest_bybit_all_symbol_open_interest_p...   103.205170
# 2005  open-interest_bitfinex_btc_usdt_open_interest_...   102.812201
# 581   taker-buy-sell-stats_bitmex_taker_buy_volume_r...   101.724799
# 1218      taker-buy-sell-stats_bybit_taker_sell_ratio_1   101.537810
# 1203      taker-buy-sell-stats_bybit_taker_buy_volume_1   101.246671
# 671   liquidations_binance_all_symbol_short_liquidat...   100.459100
# 498   tokens-transferred_tokens_transferred_mean_rol...   100.262360
# 888   taker-buy-sell-stats_htx_global_taker_buy_rati...   100.181798
# 1897                     blockreward_blockreward_usd_47   100.155251
# 1970  open-interest_deribit_btc_usd_open_interest_pc...   100.040870
# 873   taker-buy-sell-stats_all_exchange_taker_sell_r...    99.964958
# 1648                          block-bytes_block_bytes_1    99.800801
# 1896                     blockreward_blockreward_usd_23    99.756082
# 155   open-interest_all_exchange_all_symbol_open_int...    99.727149
# 2047                              supply_change_rate_47    99.685832
# 1642                   block-interval_block_interval_47    99.224510
# 379   taker-buy-sell-stats_okx_taker_buy_volume_roll...    98.500299
# 944   tokens-transferred_tokens_transferred_total_mo...    98.409732
# 1918                                 liquidation_diff_1    98.305810
# 839   open-interest_bybit_all_symbol_open_interest_d...    97.996380
# 2008  open-interest_bybit_all_symbol_open_interest_p...    97.915519
# 1727    taker-buy-sell-stats_bitmex_taker_sell_ratio_47    97.635770
# 1315  taker-buy-sell-stats_htx_global_taker_sell_vol...    97.557701
# 1533     taker-buy-sell-stats_deribit_taker_buy_ratio_1    97.438950
# 1926                            liquidation_usd_diff_23    97.386279
# 1264     taker-buy-sell-stats_binance_taker_buy_ratio_2    97.374489
# 1320  taker-buy-sell-stats_htx_global_taker_buy_ratio_5    97.368620
# 2045                               supply_change_rate_5    97.149221
# 845               liquidation_usd_ratio_rolling_mean_6h    97.044671
# 1468        taker-buy-sell-stats_okx_taker_sell_ratio_1    97.015572
# 2006  open-interest_bitfinex_btc_usdt_open_interest_...    96.841810
# 2027                           liquidation_usd_ratio_47    96.781370
# 1524    taker-buy-sell-stats_deribit_taker_buy_volume_2    96.276151
# 1459       taker-buy-sell-stats_okx_taker_sell_volume_2    96.176749
# 1271   taker-buy-sell-stats_binance_taker_sell_ratio_23    96.150969
# 794   open-interest_okx_btc_usdt_open_interest_pct_c...    96.134231
# 2015  open-interest_bybit_all_symbol_open_interest_d...    95.708999
# 154                                                hour    95.601091
# 1605       tokens-transferred_tokens_transferred_mean_5    95.498679
# 194   taker-buy-sell-stats_bybit_taker_buy_sell_rati...    94.917119
# 1976  open-interest_deribit_btc_usd_open_interest_di...    94.778211
# 1606      tokens-transferred_tokens_transferred_mean_23    94.582500
# 805   open-interest_deribit_btc_usd_open_interest_di...    94.425591
# 1481  open-interest_huobi_global_btc_usdt_open_inter...    94.386580
# 79          tokens-transferred_tokens_transferred_total    94.288260
# 1969  open-interest_deribit_btc_usd_open_interest_pc...    94.257202
# 1283  liquidations_all_exchange_all_symbol_short_liq...    94.165751
# 161   open-interest_deribit_btc_usd_open_interest_pc...    93.769312
# 68    taker-buy-sell-stats_deribit_taker_buy_sell_ratio    93.611930
# 1322  taker-buy-sell-stats_htx_global_taker_buy_rati...    93.291500
# 197   taker-buy-sell-stats_all_exchange_taker_buy_vo...    93.013802
# 1527   taker-buy-sell-stats_deribit_taker_buy_volume_47    92.718371
# 1196  open-interest_bybit_all_symbol_open_interest_d...    92.323299
# 1712    taker-buy-sell-stats_bitmex_taker_buy_volume_47    92.012529
# 1750    coinbase-premium-index_coinbase_premium_index_5    91.428241
# 1362             funding-rates_deribit_funding_rates_47    91.336161
# 1559       transactions-count_transactions_count_mean_2    91.221149
# 851       funding_rate_position_change_rolling_mean_24h    90.864799
# 1216      taker-buy-sell-stats_bybit_taker_buy_ratio_23    90.801310
# 1536    taker-buy-sell-stats_deribit_taker_buy_ratio_23    90.570700
# 2021                     liquidation_to_volume_ratio_23    90.569281
# 749                    liquidation_diff_rolling_mean_6h    90.132630
# 233   taker-buy-sell-stats_binance_taker_buy_sell_ra...    90.053359
# 911   addresses-count_addresses_count_active_moving_...    89.899879
# 1441          addresses-count_addresses_count_sender_23    89.608660
# 497   tokens-transferred_tokens_transferred_mean_rol...    89.597881
# 1960  open-interest_okx_btc_usdt_open_interest_pct_c...    89.489400
# 968   taker-buy-sell-stats_bitmex_taker_buy_ratio_mo...    89.440520
# 1455        taker-buy-sell-stats_okx_taker_buy_volume_5    89.153819
# 589   taker-buy-sell-stats_bitmex_taker_buy_ratio_ro...    89.040988
# 1638                    block-interval_block_interval_1    88.857540
# 8     taker-buy-sell-stats_all_exchange_taker_sell_r...    88.762571
# 212   taker-buy-sell-stats_all_exchange_taker_sell_r...    88.667999
# 1435           addresses-count_addresses_count_active_5    88.302341
# 852       funding_rate_position_change_rolling_mean_48h    87.794690
# 46               addresses-count_addresses_count_active    87.588600
# 2017  open-interest_bybit_all_symbol_open_interest_d...    87.457549
# 2028                     funding_rate_position_change_1    87.452419
# 569   open-interest_bybit_btc_usdt_open_interest_rol...    87.390402
# 74    liquidations_huobi_global_btc_usdt_long_liquid...    87.238600
# 1237  taker-buy-sell-stats_all_exchange_taker_sell_v...    87.231580
# 1722     taker-buy-sell-stats_bitmex_taker_buy_ratio_47    87.148779
# 2000  open-interest_bitfinex_btc_usdt_open_interest_...    87.121200
# 418   liquidations_huobi_global_all_symbol_short_liq...    87.018651
# 564   liquidations_okx_all_symbol_long_liquidations_...    86.871302
# 89                              block-bytes_block_bytes    86.693151
# 1260   taker-buy-sell-stats_binance_taker_sell_volume_5    86.657882
# 1988  open-interest_bybit_btc_usdt_open_interest_pct...    86.562742
# 450   taker-buy-sell-stats_deribit_taker_buy_sell_ra...    86.472040
# 208   taker-buy-sell-stats_all_exchange_taker_buy_ra...    86.449370
# 1458       taker-buy-sell-stats_okx_taker_sell_volume_1    86.426032
# 158    open-interest_binance_btc_usd_open_interest_diff    86.252590
# 247   liquidations_all_exchange_all_symbol_long_liqu...    86.069999
# 1953  open-interest_binance_btc_usd_open_interest_di...    86.040350
# 272   taker-buy-sell-stats_htx_global_taker_buy_rati...    85.851520
# 1996  open-interest_bybit_btc_usdt_open_interest_dif...    85.695509
# 2043                               supply_change_rate_1    85.597820
# 583   taker-buy-sell-stats_bitmex_taker_buy_volume_r...    85.213551
# 1467        taker-buy-sell-stats_okx_taker_buy_ratio_47    85.134891
# 1916      open-interest_okx_all_symbol_open_interest_23    85.052591
# 1308  taker-buy-sell-stats_htx_global_taker_buy_volu...    84.998522
# 1356    open-interest_binance_btc_usdt_open_interest_23    84.915699
# 835   open-interest_bybit_all_symbol_open_interest_p...    84.555920
# 29    liquidations_binance_btc_usdt_short_liquidatio...    84.358321
# 442   taker-buy-sell-stats_deribit_taker_buy_ratio_r...    84.165210
# 596   taker-buy-sell-stats_bitmex_taker_sell_ratio_r...    83.999829
# 833   open-interest_bybit_all_symbol_open_interest_p...    83.587399
# 874   taker-buy-sell-stats_all_exchange_taker_buy_se...    83.162429
# 798   open-interest_okx_btc_usdt_open_interest_diff_...    83.070302
# 601   liquidations_bybit_all_symbol_long_liquidation...    82.947530
# 781   open-interest_all_exchange_all_symbol_open_int...    82.807500
# 108         coinbase-premium-index_coinbase_premium_gap    82.702959
# 1470        taker-buy-sell-stats_okx_taker_sell_ratio_5    82.597380
# 1219      taker-buy-sell-stats_bybit_taker_sell_ratio_2    82.185369
# 1213       taker-buy-sell-stats_bybit_taker_buy_ratio_1    82.151940
# 1438           addresses-count_addresses_count_sender_1    82.132730
# 786   open-interest_binance_btc_usd_open_interest_pc...    81.781350
# 32          liquidations_okx_btc_usdt_long_liquidations    81.630352
# 1313  taker-buy-sell-stats_htx_global_taker_sell_vol...    81.521589
# 1433           addresses-count_addresses_count_active_1    81.519460
# 789   open-interest_binance_btc_usd_open_interest_di...    81.470469
# 193   taker-buy-sell-stats_bybit_taker_buy_sell_rati...    81.413520
# 1317  taker-buy-sell-stats_htx_global_taker_sell_vol...    81.396890
# 444   taker-buy-sell-stats_deribit_taker_buy_ratio_r...    81.286640
# 1444         addresses-count_addresses_count_receiver_2    81.236821
# 667   liquidations_binance_all_symbol_long_liquidati...    80.849901
# 1927                            liquidation_usd_diff_47    80.817648
# 295   liquidations_binance_btc_usdt_short_liquidatio...    80.809301
# 536            block-bytes_block_bytes_rolling_mean_48h    80.711761
# 199   taker-buy-sell-stats_all_exchange_taker_buy_vo...    80.364499
# 792   open-interest_binance_btc_usd_open_interest_di...    79.993330
# 952          block-interval_block_interval_moving_avg_7    79.885031
# 731        blockreward_blockreward_usd_rolling_mean_24h    79.856659
# 2016  open-interest_bybit_all_symbol_open_interest_d...    79.803199
# 1210     taker-buy-sell-stats_bybit_taker_sell_volume_5    79.558711
# 1891                         blockreward_blockreward_23    79.082180
# 48             addresses-count_addresses_count_receiver    78.635900
# 388   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...    78.520401
# 836   open-interest_bybit_all_symbol_open_interest_p...    78.263180
# 1029                 liquidation_usd_ratio_moving_avg_7    78.136971
# 1943  open-interest_all_exchange_all_symbol_open_int...    78.087880
# 802   open-interest_deribit_btc_usd_open_interest_pc...    77.881909
# 1016  open-interest_okx_btc_usdt_open_interest_pct_c...    77.843111
# 598   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...    77.741900
# 120   liquidations_binance_all_symbol_long_liquidations    77.179240
# 847              liquidation_usd_ratio_rolling_mean_24h    77.140850
# 101        taker-buy-sell-stats_bitmex_taker_buy_volume    77.129241
# 1570  liquidations_huobi_global_btc_usdt_short_liqui...    76.981900
# 1232  taker-buy-sell-stats_all_exchange_taker_buy_vo...    76.935020
# 834   open-interest_bybit_all_symbol_open_interest_p...    76.646699
# 866   taker-buy-sell-stats_bybit_taker_sell_volume_m...    76.530701
# 594   taker-buy-sell-stats_bitmex_taker_sell_ratio_r...    76.276859
# 1288  liquidations_all_exchange_all_symbol_long_liqu...    76.265100
# 2030                     funding_rate_position_change_5    76.145330
# 28    liquidations_binance_btc_usdt_long_liquidation...    75.991149
# 496   tokens-transferred_tokens_transferred_total_ro...    75.891800
# 5     taker-buy-sell-stats_all_exchange_taker_buy_vo...    75.713799
# 129      open-interest_binance_all_symbol_open_interest    75.693449
# 1309  taker-buy-sell-stats_htx_global_taker_buy_volu...    75.572371
# 674    funding-rates_okx_funding_rates_rolling_mean_12h    75.471721
# 1457       taker-buy-sell-stats_okx_taker_buy_volume_47    75.290989
# 216   taker-buy-sell-stats_all_exchange_taker_buy_se...    74.900771
# 1890                          blockreward_blockreward_5    74.825099
# 1950  open-interest_binance_btc_usd_open_interest_pc...    74.637020
# 225   taker-buy-sell-stats_binance_taker_buy_ratio_r...    74.601189
# 806   open-interest_deribit_btc_usd_open_interest_di...    74.497361
# 1019  open-interest_deribit_btc_usd_open_interest_di...    74.479549
# 1442          addresses-count_addresses_count_sender_47    74.209930
# 753                liquidation_usd_diff_rolling_mean_6h    73.701019
# 969   taker-buy-sell-stats_bitmex_taker_sell_ratio_m...    73.566289
# 560   liquidations_okx_all_symbol_short_liquidations...    73.442090
# 1337  liquidations_binance_btc_usdt_long_liquidation...    73.419270
# 192   taker-buy-sell-stats_bybit_taker_sell_ratio_ro...    73.273888
# 1340  liquidations_binance_btc_usdt_short_liquidatio...    73.198261
# 420   liquidations_huobi_global_all_symbol_short_liq...    73.190520
# 2029                     funding_rate_position_change_2    72.872370
# 1257   taker-buy-sell-stats_binance_taker_buy_volume_47    72.851810
# 837   open-interest_bybit_all_symbol_open_interest_d...    72.150960
# 207   taker-buy-sell-stats_all_exchange_taker_buy_ra...    72.076969
# 1630         fees-transaction_fees_transaction_median_5    71.993470
# 1259   taker-buy-sell-stats_binance_taker_sell_volume_2    71.857920
# 1111             funding-rates_binance_funding_rates_WT    71.855900
# 1505  liquidations_huobi_global_all_symbol_short_liq...    71.683471
# 416   liquidations_huobi_global_all_symbol_long_liqu...    71.660700
# 262   taker-buy-sell-stats_htx_global_taker_buy_volu...    71.581940
# 143                                    liquidation_diff    71.536400
# 213   taker-buy-sell-stats_all_exchange_taker_buy_se...    71.509120
# 533             block-bytes_block_bytes_rolling_mean_6h    71.161131
# 1318  taker-buy-sell-stats_htx_global_taker_buy_ratio_1    71.105750
# 597   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...    71.057992
# 236   taker-buy-sell-stats_binance_taker_buy_sell_ra...    70.854860
# 1204      taker-buy-sell-stats_bybit_taker_buy_volume_2    70.768010
# 822   open-interest_bybit_btc_usdt_open_interest_dif...    70.733001
# 1531  taker-buy-sell-stats_deribit_taker_sell_volume_23    70.467280
# 433   taker-buy-sell-stats_deribit_taker_buy_volume_...    70.427889
# 1013  open-interest_all_exchange_all_symbol_open_int...    70.211288
# 1925                             liquidation_usd_diff_5    70.189401
# 801   open-interest_deribit_btc_usd_open_interest_pc...    70.129411
# 1604       tokens-transferred_tokens_transferred_mean_2    70.104271
# 1622          fees-transaction_fees_transaction_mean_47    69.995800
# 1823                  funding-rates_okx_funding_rates_1    69.948601
# 838   open-interest_bybit_all_symbol_open_interest_d...    69.843229
# 1942  open-interest_all_exchange_all_symbol_open_int...    69.799660
# 780   open-interest_all_exchange_all_symbol_open_int...    69.750410
# 13        taker-buy-sell-stats_binance_taker_sell_ratio    69.547001
# 235   taker-buy-sell-stats_binance_taker_buy_sell_ra...    69.171181
# 595   taker-buy-sell-stats_bitmex_taker_sell_ratio_r...    68.954301
# 1496  liquidations_huobi_global_all_symbol_short_liq...    68.635870
# 305   liquidations_okx_btc_usdt_long_liquidations_ro...    68.536089
# 863                 supply_change_rate_rolling_mean_24h    68.367789
# 1596         open-interest_okx_btc_usd_open_interest_23    68.242001
# 1100    taker-buy-sell-stats_deribit_taker_buy_ratio_WT    68.135560
# 1965    open-interest_okx_btc_usdt_open_interest_diff_5    67.917251
# 261   taker-buy-sell-stats_htx_global_taker_buy_volu...    67.721889
# 1616                               hashrate_hashrate_23    67.694331
# 1293  liquidations_all_exchange_all_symbol_short_liq...    67.679158
# 1716   taker-buy-sell-stats_bitmex_taker_sell_volume_23    67.639272
# 912   addresses-count_addresses_count_sender_moving_...    67.600630
# 188   taker-buy-sell-stats_bybit_taker_buy_ratio_rol...    67.567949
# 385   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...    67.467000
# 284   liquidations_binance_btc_usdt_long_liquidation...    67.443080
# 270   taker-buy-sell-stats_htx_global_taker_buy_rati...    67.404799
# 1715    taker-buy-sell-stats_bitmex_taker_sell_volume_5    67.234661
# 1615                                hashrate_hashrate_5    67.137928
# 1627      fees-transaction_fees_transaction_mean_usd_47    67.066300
# 607   liquidations_bybit_all_symbol_long_liquidation...    66.704161
# 162    open-interest_deribit_btc_usd_open_interest_diff    66.691801
# 451   taker-buy-sell-stats_deribit_taker_buy_sell_ra...    66.431490
# 395   taker-buy-sell-stats_okx_taker_buy_sell_ratio_...    66.262199
# 796   open-interest_okx_btc_usdt_open_interest_pct_c...    66.066379
# 370   addresses-count_addresses_count_receiver_rolli...    66.001791
# 841         liquidation_to_volume_ratio_rolling_mean_6h    65.872320
# 1532  taker-buy-sell-stats_deribit_taker_sell_volume_47    65.757702
# 790   open-interest_binance_btc_usd_open_interest_di...    65.371119
# 1258   taker-buy-sell-stats_binance_taker_sell_volume_1    65.317520
# 1734  liquidations_bybit_all_symbol_long_liquidations_2    65.223260
# 886   taker-buy-sell-stats_htx_global_taker_buy_volu...    64.790519
# 57    liquidations_huobi_global_all_symbol_long_liqu...    64.698212
# 2032                    funding_rate_position_change_47    64.523400
# 1113     tokens-transferred_tokens_transferred_total_WT    64.340200
# 1717   taker-buy-sell-stats_bitmex_taker_sell_volume_47    64.285011
# 2044                               supply_change_rate_2    64.222510
# 723   open-interest_gate_io_all_symbol_open_interest...    64.179099
# 795   open-interest_okx_btc_usdt_open_interest_pct_c...    64.160141
# 1746     coinbase-premium-index_coinbase_premium_gap_23    63.822649
# 637   taker-buy-sell-stats_huobi_global_taker_sell_r...    63.623420
# 1540    taker-buy-sell-stats_deribit_taker_sell_ratio_5    63.469150
# 1289  liquidations_all_exchange_all_symbol_long_liqu...    63.458500
# 1892                         blockreward_blockreward_47    63.414940
# 280   taker-buy-sell-stats_htx_global_taker_buy_sell...    63.399010
# 309   liquidations_okx_btc_usdt_short_liquidations_r...    63.291300
# 1565  liquidations_huobi_global_btc_usdt_long_liquid...    63.277499
# 1404                                  fees_fees_total_2    63.229261
# 1963    open-interest_okx_btc_usdt_open_interest_diff_1    63.200470
# 826   open-interest_bitfinex_btc_usdt_open_interest_...    63.171400
# 1719      taker-buy-sell-stats_bitmex_taker_buy_ratio_2    62.700330
# 1922                                liquidation_diff_47    62.512870
# 1342  liquidations_binance_btc_usdt_short_liquidatio...    62.501430
# 103         taker-buy-sell-stats_bitmex_taker_buy_ratio    62.279449
# 763                  liquidation_diffg_rolling_mean_24h    62.274900
# 1262  taker-buy-sell-stats_binance_taker_sell_volume_47    62.249201
# 1242  taker-buy-sell-stats_all_exchange_taker_buy_ra...    62.152250
# 2003  open-interest_bitfinex_btc_usdt_open_interest_...    62.091431
# 727            blockreward_blockreward_rolling_mean_24h    62.089499
# 787   open-interest_binance_btc_usd_open_interest_pc...    61.913280
# 1272   taker-buy-sell-stats_binance_taker_sell_ratio_47    61.857620
# 1720      taker-buy-sell-stats_bitmex_taker_buy_ratio_5    61.781860
# 264   taker-buy-sell-stats_htx_global_taker_buy_volu...    61.723598
# 251   liquidations_all_exchange_all_symbol_short_liq...    61.495701
# 124                     funding-rates_okx_funding_rates    61.369540
# 1576  liquidations_huobi_global_btc_usdt_long_liquid...    61.078101
# 1553      transactions-count_transactions_count_total_1    60.977899
# 195   taker-buy-sell-stats_bybit_taker_buy_sell_rati...    60.957030
# 600   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...    60.862331
# 1437          addresses-count_addresses_count_active_47    60.848731
# 1095        open-interest_okx_btc_usdt_open_interest_WT    60.815480
# 494   tokens-transferred_tokens_transferred_total_ro...    60.753531
# 1632        fees-transaction_fees_transaction_median_47    60.728271
# 797   open-interest_okx_btc_usdt_open_interest_diff_...    60.632569
# 587   taker-buy-sell-stats_bitmex_taker_sell_volume_...    60.510342
# 1296  liquidations_all_exchange_all_symbol_short_liq...    60.390501
# 1708     taker-buy-sell-stats_bitmex_taker_buy_volume_1    60.342131
# 1440           addresses-count_addresses_count_sender_5    60.230559
# 1086        taker-buy-sell-stats_okx_taker_buy_ratio_WT    60.191502
# 1350  liquidations_binance_btc_usdt_short_liquidatio...    60.039861
# 592   taker-buy-sell-stats_bitmex_taker_buy_ratio_ro...    59.944420
# 1525    taker-buy-sell-stats_deribit_taker_buy_volume_5    59.921600
# 386   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...    59.899660
# 1542   taker-buy-sell-stats_deribit_taker_sell_ratio_47    59.821680
# 1714    taker-buy-sell-stats_bitmex_taker_sell_volume_2    59.804060
# 1664      open-interest_gate_io_btc_usd_open_interest_2    59.710901
# 1974  open-interest_deribit_btc_usd_open_interest_di...    59.690539
# 1081          addresses-count_addresses_count_sender_WT    59.404100
# 1083      open-interest_kraken_btc_usd_open_interest_WT    59.381598
# 807   open-interest_deribit_btc_usd_open_interest_di...    59.191390
# 879   taker-buy-sell-stats_binance_taker_buy_sell_ra...    59.152771
# 590   taker-buy-sell-stats_bitmex_taker_buy_ratio_ro...    59.130589
# 611   coinbase-premium-index_coinbase_premium_gap_ro...    59.009279
# 954                block-bytes_block_bytes_moving_avg_7    58.978679
# 588   taker-buy-sell-stats_bitmex_taker_sell_volume_...    58.969100
# 439   taker-buy-sell-stats_deribit_taker_sell_volume...    58.940740
# 867   taker-buy-sell-stats_bybit_taker_buy_ratio_mov...    58.790959
# 1184  open-interest_binance_btc_usd_open_interest_di...    58.789902
# 1526   taker-buy-sell-stats_deribit_taker_buy_volume_23    58.687500
# 1914       open-interest_okx_all_symbol_open_interest_2    58.576700

# %%
# 모델 학습 후 특성 중요도 확인
feature_importance = lgb_model.feature_importance(importance_type='split')
feature_names = lgb_model.feature_name()

# 특성 중요도를 데이터프레임으로 변환하고 정렬
import pandas as pd
feature_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importance
}).sort_values('importance', ascending=False)

print(feature_importance_df)

# 상위 30개 특성의 중요도를 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(feature_importance_df['feature'][:30], feature_importance_df['importance'][:30])
plt.xticks(rotation=90)
plt.title('Top 20 Feature Importance')
plt.tight_layout()
plt.show()
# Out:
#                                                 feature  importance
# 1110  open-interest_huobi_global_all_symbol_open_int...          41
# 1602     tokens-transferred_tokens_transferred_total_47          26
# 1025  open-interest_bitfinex_btc_usdt_open_interest_...          25
# 102       taker-buy-sell-stats_bitmex_taker_sell_volume          24
# 1464         taker-buy-sell-stats_okx_taker_buy_ratio_2          22
# ...                                                 ...         ...
# 2034                                     premium_diff_2           0
# 2035                                     premium_diff_5           0
# 2038                           hashrate_to_difficulty_1           0
# 2039                           hashrate_to_difficulty_2           0
# 2040                           hashrate_to_difficulty_5           0
#
# [2048 rows x 2 columns]

# %%
# split importance 기준으로 오름차순 정렬
feature_importance_df_sorted = feature_importance_df.sort_values('importance', ascending=True)

# 하위 n개 선택
n = 500
bottom = feature_importance_df_sorted.head(n)

# 결과 출력 (모든 행 표시)
print(f"하위 {n}개 특성:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(bottom)
# Out:
# 하위 500개 특성:
#                                                 feature  importance
# 1077     open-interest_deribit_btc_usd_open_interest_WT           0
# 357                   supply_supply_new_rolling_mean_6h           0
# 358                  supply_supply_new_rolling_mean_12h           0
# 360                  supply_supply_new_rolling_mean_48h           0
# 1130  liquidations_okx_all_symbol_long_liquidations_...           0
# 1132      open-interest_bybit_btc_usdt_open_interest_WT           0
# 1059  taker-buy-sell-stats_htx_global_taker_buy_sell...           0
# 1060  liquidations_binance_btc_usdt_long_liquidation...           0
# 1063  liquidations_binance_btc_usdt_short_liquidatio...           0
# 1071  open-interest_htx_global_btc_usd_open_interest_WT           0
# 1076                        fees_fees_reward_percent_WT           0
# 356                supply_supply_total_rolling_mean_48h           0
# 1078                             supply_supply_total_WT           0
# 1080          addresses-count_addresses_count_active_WT           0
# 1084       taker-buy-sell-stats_okx_taker_buy_volume_WT           0
# 1085      taker-buy-sell-stats_okx_taker_sell_volume_WT           0
# 1088   taker-buy-sell-stats_okx_taker_buy_sell_ratio_WT           0
# 1091  liquidations_huobi_global_all_symbol_long_liqu...           0
# 1092  liquidations_huobi_global_all_symbol_short_liq...           0
# 1096                  velocity_velocity_supply_total_WT           0
# 1474    taker-buy-sell-stats_okx_taker_buy_sell_ratio_2           0
# 1477   taker-buy-sell-stats_okx_taker_buy_sell_ratio_47           0
# 1548    open-interest_kraken_all_symbol_open_interest_1           0
# 1513                   velocity_velocity_supply_total_1           0
# 1514                   velocity_velocity_supply_total_2           0
# 1515                   velocity_velocity_supply_total_5           0
# 1516                  velocity_velocity_supply_total_23           0
# 1517                  velocity_velocity_supply_total_47           0
# 1518    open-interest_bitmex_all_symbol_open_interest_1           0
# 1519    open-interest_bitmex_all_symbol_open_interest_2           0
# 1520    open-interest_bitmex_all_symbol_open_interest_5           0
# 1521   open-interest_bitmex_all_symbol_open_interest_23           0
# 1522   open-interest_bitmex_all_symbol_open_interest_47           0
# 1492  liquidations_huobi_global_all_symbol_long_liqu...           0
# 1549    open-interest_kraken_all_symbol_open_interest_2           0
# 1550    open-interest_kraken_all_symbol_open_interest_5           0
# 1551   open-interest_kraken_all_symbol_open_interest_23           0
# 1010                           volume_diff_moving_avg_7           0
# 1020  open-interest_deribit_all_symbol_open_interest...           0
# 1021  open-interest_deribit_all_symbol_open_interest...           0
# 353                 supply_supply_total_rolling_mean_6h           0
# 354                supply_supply_total_rolling_mean_12h           0
# 355                supply_supply_total_rolling_mean_24h           0
# 1103   open-interest_kraken_all_symbol_open_interest_WT           0
# 1161  liquidations_htx_global_all_symbol_long_liquid...           0
# 1162  liquidations_htx_global_all_symbol_short_liqui...           0
# 1164  open-interest_htx_global_btc_usdt_open_interes...           0
# 224   taker-buy-sell-stats_binance_taker_sell_volume...           0
# 226   taker-buy-sell-stats_binance_taker_buy_ratio_r...           0
# 230   taker-buy-sell-stats_binance_taker_sell_ratio_...           0
# 241   liquidations_all_exchange_all_symbol_short_liq...           0
# 253   open-interest_huobi_global_btc_usd_open_intere...           0
# 1097   open-interest_bitmex_all_symbol_open_interest_WT           0
# 1102  taker-buy-sell-stats_deribit_taker_buy_sell_ra...           0
# 1160  liquidations_htx_global_all_symbol_short_liqui...           0
# 1105      transactions-count_transactions_count_mean_WT           0
# 1106  liquidations_huobi_global_btc_usdt_long_liquid...           0
# 1107  liquidations_huobi_global_btc_usdt_short_liqui...           0
# 1108  liquidations_huobi_global_btc_usdt_long_liquid...           0
# 1114      tokens-transferred_tokens_transferred_mean_WT           0
# 1115    tokens-transferred_tokens_transferred_median_WT           0
# 1116                               hashrate_hashrate_WT           0
# 1117          fees-transaction_fees_transaction_mean_WT           0
# 1118      fees-transaction_fees_transaction_mean_usd_WT           0
# 1043  taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 1503  liquidations_huobi_global_all_symbol_short_liq...           0
# 1031                          premium_diff_moving_avg_7           0
# 1032                hashrate_to_difficulty_moving_avg_7           0
# 1034     taker-buy-sell-stats_bybit_taker_buy_volume_WT           0
# 1035    taker-buy-sell-stats_bybit_taker_sell_volume_WT           0
# 1037     taker-buy-sell-stats_bybit_taker_sell_ratio_WT           0
# 1038  taker-buy-sell-stats_bybit_taker_buy_sell_rati...           0
# 1039  taker-buy-sell-stats_all_exchange_taker_buy_vo...           0
# 1040  taker-buy-sell-stats_all_exchange_taker_sell_v...           0
# 1042  taker-buy-sell-stats_all_exchange_taker_sell_r...           0
# 1510         open-interest_okx_btc_usdt_open_interest_5           0
# 1044   taker-buy-sell-stats_binance_taker_buy_volume_WT           0
# 1045  taker-buy-sell-stats_binance_taker_sell_volume_WT           0
# 1141  liquidations_bybit_all_symbol_long_liquidation...           0
# 1144  open-interest_deribit_all_symbol_open_interest_WT           0
# 44                                  supply_supply_total           0
# 1152          funding-rates_htx_global_funding_rates_WT           0
# 1153  open-interest_bitfinex_all_symbol_open_interes...           0
# 1155  liquidations_binance_all_symbol_short_liquidat...           0
# 1159  liquidations_htx_global_all_symbol_long_liquid...           0
# 1578  liquidations_huobi_global_btc_usdt_short_liqui...           0
# 957   open-interest_gate_io_btc_usd_open_interest_mo...           0
# 958   open-interest_bybit_all_symbol_open_interest_m...           0
# 959   liquidations_okx_all_symbol_long_liquidations_...           0
# 964   open-interest_all_exchange_all_symbol_open_int...           0
# 965   open-interest_htx_global_all_symbol_open_inter...           0
# 975   open-interest_deribit_all_symbol_open_interest...           0
# 976   open-interest_bybit_btc_usd_open_interest_movi...           0
# 1569  liquidations_huobi_global_btc_usdt_short_liqui...           0
# 1572  liquidations_huobi_global_btc_usdt_short_liqui...           0
# 1574  liquidations_huobi_global_btc_usdt_long_liquid...           0
# 955   open-interest_gate_io_btc_usdt_open_interest_m...           0
# 1581  liquidations_huobi_global_btc_usdt_short_liqui...           0
# 1583  open-interest_huobi_global_all_symbol_open_int...           0
# 1589              funding-rates_binance_funding_rates_2           0
# 1595          open-interest_okx_btc_usd_open_interest_5           0
# 163   open-interest_deribit_all_symbol_open_interest...           0
# 164   open-interest_deribit_all_symbol_open_interest...           0
# 900   liquidations_okx_btc_usdt_short_liquidations_u...           0
# 901   open-interest_bitfinex_btc_usdt_open_interest_...           0
# 902   open-interest_htx_global_btc_usd_open_interest...           0
# 903                   fees_fees_block_mean_moving_avg_7           0
# 1625       fees-transaction_fees_transaction_mean_usd_5           0
# 397   open-interest_huobi_global_btc_usdt_open_inter...           0
# 401   funding-rates_all_exchange_funding_rates_rolli...           0
# 402   funding-rates_all_exchange_funding_rates_rolli...           0
# 403   funding-rates_all_exchange_funding_rates_rolli...           0
# 407   liquidations_huobi_global_all_symbol_long_liqu...           0
# 408   liquidations_huobi_global_all_symbol_long_liqu...           0
# 174                                        premium_diff           0
# 175                              hashrate_to_difficulty           0
# 183   taker-buy-sell-stats_bybit_taker_sell_volume_r...           0
# 191   taker-buy-sell-stats_bybit_taker_sell_ratio_ro...           0
# 904               fees_fees_block_mean_usd_moving_avg_7           0
# 1626      fees-transaction_fees_transaction_mean_usd_23           0
# 809   open-interest_deribit_all_symbol_open_interest...           0
# 937   liquidations_huobi_global_btc_usdt_long_liquid...           0
# 940   liquidations_huobi_global_btc_usdt_short_liqui...           0
# 943   open-interest_okx_btc_usd_open_interest_moving...           0
# 948   fees-transaction_fees_transaction_mean_moving_...           0
# 949   fees-transaction_fees_transaction_mean_usd_mov...           0
# 950   fees-transaction_fees_transaction_median_movin...           0
# 951   fees-transaction_fees_transaction_median_usd_m...           0
# 203   taker-buy-sell-stats_all_exchange_taker_sell_v...           0
# 997   liquidations_htx_global_btc_usdt_long_liquidat...           0
# 998   liquidations_htx_global_btc_usdt_short_liquida...           0
# 999   liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1000  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1001  open-interest_gate_io_all_symbol_open_interest...           0
# 1004                 difficulty_difficulty_moving_avg_7           0
# 1005                 utxo-count_utxo_count_moving_avg_7           0
# 1008                      liquidation_diff_moving_avg_7           0
# 1552   open-interest_kraken_all_symbol_open_interest_47           0
# 1564  liquidations_huobi_global_btc_usdt_long_liquid...           0
# 996                block-count_block_count_moving_avg_7           0
# 204   taker-buy-sell-stats_all_exchange_taker_sell_v...           0
# 218   taker-buy-sell-stats_binance_taker_buy_volume_...           0
# 1047   taker-buy-sell-stats_binance_taker_sell_ratio_WT           0
# 1049  liquidations_all_exchange_all_symbol_long_liqu...           0
# 1050  liquidations_all_exchange_all_symbol_short_liq...           0
# 1054      open-interest_bitmex_btc_usd_open_interest_WT           0
# 1055  taker-buy-sell-stats_htx_global_taker_buy_volu...           0
# 1056  taker-buy-sell-stats_htx_global_taker_sell_vol...           0
# 1509         open-interest_okx_btc_usdt_open_interest_2           0
# 981   taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 906                    fees_fees_total_usd_moving_avg_7           0
# 907               fees_fees_reward_percent_moving_avg_7           0
# 368   addresses-count_addresses_count_sender_rolling...           0
# 371   addresses-count_addresses_count_receiver_rolli...           0
# 373   open-interest_kraken_btc_usd_open_interest_rol...           0
# 376   open-interest_kraken_btc_usd_open_interest_rol...           0
# 378   taker-buy-sell-stats_okx_taker_buy_volume_roll...           0
# 977   taker-buy-sell-stats_huobi_global_taker_buy_vo...           0
# 978   taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 979   taker-buy-sell-stats_huobi_global_taker_buy_ra...           0
# 1120    fees-transaction_fees_transaction_median_usd_WT           0
# 983   funding-rates_htx_global_funding_rates_moving_...           0
# 984   open-interest_bitfinex_all_symbol_open_interes...           0
# 987   liquidations_binance_all_symbol_long_liquidati...           0
# 990   liquidations_htx_global_all_symbol_long_liquid...           0
# 991   liquidations_htx_global_all_symbol_short_liqui...           0
# 992   liquidations_htx_global_all_symbol_long_liquid...           0
# 993   liquidations_htx_global_all_symbol_short_liqui...           0
# 994   open-interest_binance_all_symbol_open_interest...           0
# 995   open-interest_htx_global_btc_usdt_open_interes...           0
# 119     open-interest_bitfinex_all_symbol_open_interest           0
# 571   open-interest_bybit_btc_usdt_open_interest_rol...           0
# 572   open-interest_bybit_btc_usdt_open_interest_rol...           0
# 574   open-interest_all_exchange_all_symbol_open_int...           0
# 575   open-interest_all_exchange_all_symbol_open_int...           0
# 576   open-interest_all_exchange_all_symbol_open_int...           0
# 577   open-interest_htx_global_all_symbol_open_inter...           0
# 578   open-interest_htx_global_all_symbol_open_inter...           0
# 579   open-interest_htx_global_all_symbol_open_inter...           0
# 580   open-interest_htx_global_all_symbol_open_inter...           0
# 118              funding-rates_htx_global_funding_rates           0
# 568   liquidations_okx_all_symbol_short_liquidations...           0
# 122   liquidations_binance_all_symbol_long_liquidati...           0
# 125   liquidations_htx_global_all_symbol_long_liquid...           0
# 126   liquidations_htx_global_all_symbol_short_liqui...           0
# 127   liquidations_htx_global_all_symbol_long_liquid...           0
# 1928                                      volume_diff_1           0
# 1929                                      volume_diff_2           0
# 1930                                      volume_diff_5           0
# 1931                                     volume_diff_23           0
# 1932                                     volume_diff_47           0
# 1933                            buy_sell_volume_ratio_1           0
# 1245  taker-buy-sell-stats_all_exchange_taker_sell_r...           0
# 1384    open-interest_bitfinex_btc_usdt_open_interest_2           0
# 1388   open-interest_htx_global_btc_usd_open_interest_1           0
# 1389   open-interest_htx_global_btc_usd_open_interest_2           0
# 1390   open-interest_htx_global_btc_usd_open_interest_5           0
# 1391  open-interest_htx_global_btc_usd_open_interest_23           0
# 1392  open-interest_htx_global_btc_usd_open_interest_47           0
# 351   open-interest_deribit_btc_usd_open_interest_ro...           0
# 1224  taker-buy-sell-stats_bybit_taker_buy_sell_ratio_2           0
# 1225  taker-buy-sell-stats_bybit_taker_buy_sell_ratio_5           0
# 1233  taker-buy-sell-stats_all_exchange_taker_sell_v...           0
# 1936                           buy_sell_volume_ratio_23           0
# 1248  taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 1249  taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 1250  taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 1251  taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 629   taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 630   taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 631   taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 632   taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 565   liquidations_okx_all_symbol_short_liquidations...           0
# 1985  open-interest_deribit_all_symbol_open_interest...           0
# 2042                          hashrate_to_difficulty_47           0
# 40                                      fees_fees_total           0
# 42                             fees_fees_reward_percent           0
# 1303       open-interest_bitmex_btc_usd_open_interest_1           0
# 1304       open-interest_bitmex_btc_usd_open_interest_2           0
# 1305       open-interest_bitmex_btc_usd_open_interest_5           0
# 1306      open-interest_bitmex_btc_usd_open_interest_23           0
# 62                       velocity_velocity_supply_total           0
# 63        open-interest_bitmex_all_symbol_open_interest           0
# 1984  open-interest_deribit_all_symbol_open_interest...           0
# 2041                          hashrate_to_difficulty_23           0
# 618   open-interest_deribit_all_symbol_open_interest...           0
# 1328  taker-buy-sell-stats_htx_global_taker_buy_sell...           0
# 1344  liquidations_binance_btc_usdt_long_liquidation...           0
# 1345  liquidations_binance_btc_usdt_long_liquidation...           0
# 1353     open-interest_binance_btc_usdt_open_interest_1           0
# 2038                           hashrate_to_difficulty_1           0
# 2039                           hashrate_to_difficulty_2           0
# 2040                           hashrate_to_difficulty_5           0
# 95       liquidations_okx_all_symbol_short_liquidations           0
# 54        taker-buy-sell-stats_okx_taker_buy_sell_ratio           0
# 69        open-interest_kraken_all_symbol_open_interest           0
# 73    liquidations_huobi_global_btc_usdt_short_liqui...           0
# 518   fees-transaction_fees_transaction_median_rolli...           0
# 519   fees-transaction_fees_transaction_median_rolli...           0
# 33         liquidations_okx_btc_usdt_short_liquidations           0
# 4       taker-buy-sell-stats_bybit_taker_buy_sell_ratio           0
# 9     taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 14    taker-buy-sell-stats_binance_taker_buy_sell_ratio           0
# 456   open-interest_kraken_all_symbol_open_interest_...           0
# 45                                    supply_supply_new           0
# 1380  liquidations_okx_btc_usdt_short_liquidations_u...           0
# 58    liquidations_huobi_global_all_symbol_short_liq...           0
# 24     taker-buy-sell-stats_htx_global_taker_sell_ratio           0
# 31                  funding-rates_deribit_funding_rates           0
# 2033                                     premium_diff_1           0
# 2034                                     premium_diff_2           0
# 1986  open-interest_deribit_all_symbol_open_interest...           0
# 1987  open-interest_deribit_all_symbol_open_interest...           0
# 315   liquidations_okx_btc_usdt_long_liquidations_us...           0
# 316   liquidations_okx_btc_usdt_long_liquidations_us...           0
# 1431                               supply_supply_new_23           0
# 1416                        fees_fees_reward_percent_23           0
# 1417                        fees_fees_reward_percent_47           0
# 1418      open-interest_deribit_btc_usd_open_interest_1           0
# 1420      open-interest_deribit_btc_usd_open_interest_5           0
# 1423                              supply_supply_total_1           0
# 1424                              supply_supply_total_2           0
# 1425                              supply_supply_total_5           0
# 1426                             supply_supply_total_23           0
# 1427                             supply_supply_total_47           0
# 1428                                supply_supply_new_1           0
# 1415                         fees_fees_reward_percent_5           0
# 1432                               supply_supply_new_47           0
# 1133  open-interest_all_exchange_all_symbol_open_int...           0
# 1140  liquidations_bybit_all_symbol_long_liquidation...           0
# 1252  taker-buy-sell-stats_all_exchange_taker_buy_se...           0
# 1253    taker-buy-sell-stats_binance_taker_buy_volume_1           0
# 1254    taker-buy-sell-stats_binance_taker_buy_volume_2           0
# 1256   taker-buy-sell-stats_binance_taker_buy_volume_23           0
# 321   open-interest_bitfinex_btc_usdt_open_interest_...           0
# 323   open-interest_bitfinex_btc_usdt_open_interest_...           0
# 1176      open-interest_okx_all_symbol_open_interest_WT           0
# 1123                         block-bytes_block_bytes_WT           0
# 1126     open-interest_gate_io_btc_usd_open_interest_WT           0
# 1127    open-interest_bybit_all_symbol_open_interest_WT           0
# 1167  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1169  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1170  open-interest_gate_io_all_symbol_open_interest_WT           0
# 1172                     blockreward_blockreward_usd_WT           0
# 1173                           difficulty_difficulty_WT           0
# 1174                           utxo-count_utxo_count_WT           0
# 1175     open-interest_binance_btc_usd_open_interest_WT           0
# 325   open-interest_htx_global_btc_usd_open_interest...           0
# 1177                                liquidation_diff_WT           0
# 1178                            liquidation_usd_diff_WT           0
# 1179                                     volume_diff_WT           0
# 1180                           buy_sell_volume_ratio_WT           0
# 1191  open-interest_bybit_btc_usdt_open_interest_pct...           0
# 1199                    funding_rate_position_change_WT           0
# 1200                                    premium_diff_WT           0
# 1413                         fees_fees_reward_percent_1           0
# 1414                         fees_fees_reward_percent_2           0
# 310   liquidations_okx_btc_usdt_short_liquidations_r...           0
# 258   open-interest_bitmex_btc_usd_open_interest_rol...           0
# 259   open-interest_bitmex_btc_usd_open_interest_rol...           0
# 274   taker-buy-sell-stats_htx_global_taker_sell_rat...           0
# 1166  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 297   open-interest_binance_btc_usdt_open_interest_r...           0
# 298   open-interest_binance_btc_usdt_open_interest_r...           0
# 299   open-interest_binance_btc_usdt_open_interest_r...           0
# 300   open-interest_binance_btc_usdt_open_interest_r...           0
# 304   funding-rates_deribit_funding_rates_rolling_me...           0
# 308   liquidations_okx_btc_usdt_long_liquidations_ro...           0
# 1401                        fees_fees_block_mean_usd_23           0
# 1273  taker-buy-sell-stats_binance_taker_buy_sell_ra...           0
# 1274  taker-buy-sell-stats_binance_taker_buy_sell_ra...           0
# 1275  taker-buy-sell-stats_binance_taker_buy_sell_ra...           0
# 1276  taker-buy-sell-stats_binance_taker_buy_sell_ra...           0
# 1277  taker-buy-sell-stats_binance_taker_buy_sell_ra...           0
# 1369     liquidations_okx_btc_usdt_short_liquidations_2           0
# 1372    liquidations_okx_btc_usdt_short_liquidations_47           0
# 1373  liquidations_okx_btc_usdt_long_liquidations_usd_1           0
# 1374  liquidations_okx_btc_usdt_long_liquidations_usd_2           0
# 342                fees_fees_total_usd_rolling_mean_12h           0
# 326   open-interest_htx_global_btc_usd_open_interest...           0
# 327   open-interest_htx_global_btc_usd_open_interest...           0
# 328   open-interest_htx_global_btc_usd_open_interest...           0
# 330               fees_fees_block_mean_rolling_mean_12h           0
# 331               fees_fees_block_mean_rolling_mean_24h           0
# 333            fees_fees_block_mean_usd_rolling_mean_6h           0
# 335           fees_fees_block_mean_usd_rolling_mean_24h           0
# 336           fees_fees_block_mean_usd_rolling_mean_48h           0
# 339                    fees_fees_total_rolling_mean_24h           0
# 341                 fees_fees_total_usd_rolling_mean_6h           0
# 1147  taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 343                fees_fees_total_usd_rolling_mean_24h           0
# 344                fees_fees_total_usd_rolling_mean_48h           0
# 345            fees_fees_reward_percent_rolling_mean_6h           0
# 346           fees_fees_reward_percent_rolling_mean_12h           0
# 347           fees_fees_reward_percent_rolling_mean_24h           0
# 348           fees_fees_reward_percent_rolling_mean_48h           0
# 349   open-interest_deribit_btc_usd_open_interest_ro...           0
# 1399                         fees_fees_block_mean_usd_2           0
# 1400                         fees_fees_block_mean_usd_5           0
# 1854  open-interest_htx_global_btc_usdt_open_interest_2           0
# 1840  liquidations_htx_global_all_symbol_long_liquid...           0
# 1841  liquidations_htx_global_all_symbol_long_liquid...           0
# 1842  liquidations_htx_global_all_symbol_long_liquid...           0
# 1843  liquidations_htx_global_all_symbol_short_liqui...           0
# 1844  liquidations_htx_global_all_symbol_short_liqui...           0
# 1845  liquidations_htx_global_all_symbol_short_liqui...           0
# 1846  liquidations_htx_global_all_symbol_short_liqui...           0
# 1847  liquidations_htx_global_all_symbol_short_liqui...           0
# 1850   open-interest_binance_all_symbol_open_interest_5           0
# 1853  open-interest_htx_global_btc_usdt_open_interest_1           0
# 1839  liquidations_htx_global_all_symbol_long_liquid...           0
# 1855  open-interest_htx_global_btc_usdt_open_interest_5           0
# 1856  open-interest_htx_global_btc_usdt_open_interes...           0
# 1857  open-interest_htx_global_btc_usdt_open_interes...           0
# 1858                          block-count_block_count_1           0
# 1859                          block-count_block_count_2           0
# 1860                          block-count_block_count_5           0
# 1861                         block-count_block_count_23           0
# 1862                         block-count_block_count_47           0
# 1863  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1864  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 670   liquidations_binance_all_symbol_short_liquidat...           0
# 1900                            difficulty_difficulty_5           0
# 1901                           difficulty_difficulty_23           0
# 1902                           difficulty_difficulty_47           0
# 634   taker-buy-sell-stats_huobi_global_taker_buy_ra...           0
# 635   taker-buy-sell-stats_huobi_global_taker_buy_ra...           0
# 638   taker-buy-sell-stats_huobi_global_taker_sell_r...           0
# 639   taker-buy-sell-stats_huobi_global_taker_sell_r...           0
# 453   open-interest_kraken_all_symbol_open_interest_...           0
# 454   open-interest_kraken_all_symbol_open_interest_...           0
# 455   open-interest_kraken_all_symbol_open_interest_...           0
# 705   liquidations_htx_global_btc_usdt_long_liquidat...           0
# 672   liquidations_binance_all_symbol_short_liquidat...           0
# 1831  liquidations_htx_global_all_symbol_long_liquid...           0
# 1832  liquidations_htx_global_all_symbol_long_liquid...           0
# 1833  liquidations_htx_global_all_symbol_short_liqui...           0
# 1834  liquidations_htx_global_all_symbol_short_liqui...           0
# 1835  liquidations_htx_global_all_symbol_short_liqui...           0
# 1836  liquidations_htx_global_all_symbol_short_liqui...           0
# 1837  liquidations_htx_global_all_symbol_short_liqui...           0
# 1838  liquidations_htx_global_all_symbol_long_liquid...           0
# 1786  taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 649   funding-rates_htx_global_funding_rates_rolling...           0
# 650   funding-rates_htx_global_funding_rates_rolling...           0
# 651   funding-rates_htx_global_funding_rates_rolling...           0
# 652   funding-rates_htx_global_funding_rates_rolling...           0
# 653   open-interest_bitfinex_all_symbol_open_interes...           0
# 654   open-interest_bitfinex_all_symbol_open_interes...           0
# 655   open-interest_bitfinex_all_symbol_open_interes...           0
# 656   open-interest_bitfinex_all_symbol_open_interes...           0
# 665   liquidations_binance_all_symbol_long_liquidati...           0
# 668   liquidations_binance_all_symbol_long_liquidati...           0
# 644   taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 1787  taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 1790               funding-rates_bitmex_funding_rates_5           0
# 1793           funding-rates_htx_global_funding_rates_1           0
# 1794           funding-rates_htx_global_funding_rates_2           0
# 1795           funding-rates_htx_global_funding_rates_5           0
# 677   liquidations_htx_global_all_symbol_long_liquid...           0
# 678   liquidations_htx_global_all_symbol_long_liquid...           0
# 679   liquidations_htx_global_all_symbol_long_liquid...           0
# 680   liquidations_htx_global_all_symbol_long_liquid...           0
# 1818  liquidations_binance_all_symbol_short_liquidat...           0
# 1796          funding-rates_htx_global_funding_rates_23           0
# 1797          funding-rates_htx_global_funding_rates_47           0
# 1798  open-interest_bitfinex_all_symbol_open_interest_1           0
# 1799  open-interest_bitfinex_all_symbol_open_interest_2           0
# 1800  open-interest_bitfinex_all_symbol_open_interest_5           0
# 1801  open-interest_bitfinex_all_symbol_open_interes...           0
# 1802  open-interest_bitfinex_all_symbol_open_interes...           0
# 1804  liquidations_binance_all_symbol_long_liquidati...           0
# 1805  liquidations_binance_all_symbol_long_liquidati...           0
# 1807  liquidations_binance_all_symbol_long_liquidati...           0
# 1899                            difficulty_difficulty_2           0
# 1822  liquidations_binance_all_symbol_short_liquidat...           0
# 1828  liquidations_htx_global_all_symbol_long_liquid...           0
# 1829  liquidations_htx_global_all_symbol_long_liquid...           0
# 1830  liquidations_htx_global_all_symbol_long_liquid...           0
# 479   liquidations_huobi_global_btc_usdt_short_liqui...           0
# 640   taker-buy-sell-stats_huobi_global_taker_sell_r...           0
# 641   taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 642   taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 643   taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 462   transactions-count_transactions_count_mean_rol...           0
# 92          open-interest_gate_io_btc_usd_open_interest           0
# 93         open-interest_bybit_all_symbol_open_interest           0
# 1978  open-interest_deribit_all_symbol_open_interest...           0
# 1979  open-interest_deribit_all_symbol_open_interest...           0
# 1980  open-interest_deribit_all_symbol_open_interest...           0
# 1981  open-interest_deribit_all_symbol_open_interest...           0
# 1982  open-interest_deribit_all_symbol_open_interest...           0
# 1983  open-interest_deribit_all_symbol_open_interest...           0
# 19     open-interest_huobi_global_btc_usd_open_interest           0
# 521   fees-transaction_fees_transaction_median_usd_r...           0
# 88             funding-rates_huobi_global_funding_rates           0
# 470   liquidations_huobi_global_btc_usdt_short_liqui...           0
# 476   liquidations_huobi_global_btc_usdt_long_liquid...           0
# 1904                            utxo-count_utxo_count_2           0
# 1905                            utxo-count_utxo_count_5           0
# 1906                           utxo-count_utxo_count_23           0
# 1907                           utxo-count_utxo_count_47           0
# 1908      open-interest_binance_btc_usd_open_interest_1           0
# 1913       open-interest_okx_all_symbol_open_interest_1           0
# 98           open-interest_bybit_btc_usdt_open_interest           0
# 550   open-interest_bybit_all_symbol_open_interest_r...           0
# 522   fees-transaction_fees_transaction_median_usd_r...           0
# 523   fees-transaction_fees_transaction_median_usd_r...           0
# 524   fees-transaction_fees_transaction_median_usd_r...           0
# 525       block-interval_block_interval_rolling_mean_6h           0
# 537   open-interest_gate_io_btc_usdt_open_interest_r...           0
# 538   open-interest_gate_io_btc_usdt_open_interest_r...           0
# 541   funding-rates_bybit_funding_rates_rolling_mean_6h           0
# 545   open-interest_gate_io_btc_usd_open_interest_ro...           0
# 547   open-interest_gate_io_btc_usd_open_interest_ro...           0
# 549   open-interest_bybit_all_symbol_open_interest_r...           0
# 100   open-interest_htx_global_all_symbol_open_interest           0
# 551   open-interest_bybit_all_symbol_open_interest_r...           0
# 486   funding-rates_binance_funding_rates_rolling_me...           0
# 487   funding-rates_binance_funding_rates_rolling_me...           0
# 493   tokens-transferred_tokens_transferred_total_ro...           0
# 509   fees-transaction_fees_transaction_mean_rolling...           0
# 511   fees-transaction_fees_transaction_mean_rolling...           0
# 513   fees-transaction_fees_transaction_mean_usd_rol...           0
# 515   fees-transaction_fees_transaction_mean_usd_rol...           0
# 86         fees-transaction_fees_transaction_median_usd           0
# 1876  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1866  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1867  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1868  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1869  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1870  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1871  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1872  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1873  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1874  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1875  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1865  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1877  liquidations_htx_global_btc_usdt_long_liquidat...           0
# 1878  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1879  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1880  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1881  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1882  liquidations_htx_global_btc_usdt_short_liquida...           0
# 1885   open-interest_gate_io_all_symbol_open_interest_5           0
# 1887  open-interest_gate_io_all_symbol_open_interest_47           0
# 1898                            difficulty_difficulty_1           0
# 616   coinbase-premium-index_coinbase_premium_index_...           0
# 105    taker-buy-sell-stats_bitmex_taker_buy_sell_ratio           0
# 110      open-interest_deribit_all_symbol_open_interest           0
# 112   taker-buy-sell-stats_huobi_global_taker_buy_vo...           0
# 113   taker-buy-sell-stats_huobi_global_taker_sell_v...           0
# 115   taker-buy-sell-stats_huobi_global_taker_sell_r...           0
# 116   taker-buy-sell-stats_huobi_global_taker_buy_se...           0
# 606   liquidations_bybit_all_symbol_long_liquidation...           0
# 610   coinbase-premium-index_coinbase_premium_gap_ro...           0
# 612   coinbase-premium-index_coinbase_premium_gap_ro...           0
# 613   coinbase-premium-index_coinbase_premium_index_...           0
# 859             hashrate_to_difficulty_rolling_mean_24h           0
# 617   open-interest_deribit_all_symbol_open_interest...           0

# %%
# split importance 기준으로 내림차순 정렬
feature_importance_df_sorted = feature_importance_df.sort_values('importance', ascending=False)

# 상위 n개 선택
n = 500
bottom = feature_importance_df_sorted.head(n)

# 결과 출력 (모든 행 표시)
print(f"상위 {n}개 특성:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(bottom)
# Out:
# 하위 500개 특성:
#                                                 feature  importance
# 1110  open-interest_huobi_global_all_symbol_open_int...          41
# 1602     tokens-transferred_tokens_transferred_total_47          26
# 1025  open-interest_bitfinex_btc_usdt_open_interest_...          25
# 102       taker-buy-sell-stats_bitmex_taker_sell_volume          24
# 1464         taker-buy-sell-stats_okx_taker_buy_ratio_2          22
# 168   open-interest_bitfinex_btc_usdt_open_interest_...          21
# 1064    open-interest_binance_btc_usdt_open_interest_WT          21
# 1447        addresses-count_addresses_count_receiver_47          20
# 65       taker-buy-sell-stats_deribit_taker_sell_volume          20
# 1316  taker-buy-sell-stats_htx_global_taker_sell_vol...          20
# 586   taker-buy-sell-stats_bitmex_taker_sell_volume_...          20
# 171                         liquidation_to_volume_ratio          20
# 167   open-interest_bitfinex_btc_usdt_open_interest_...          20
# 1989  open-interest_bybit_btc_usdt_open_interest_pct...          19
# 64        taker-buy-sell-stats_deribit_taker_buy_volume          19
# 10        taker-buy-sell-stats_binance_taker_buy_volume          19
# 1214       taker-buy-sell-stats_bybit_taker_buy_ratio_2          19
# 865   taker-buy-sell-stats_bybit_taker_buy_volume_mo...          18
# 2001  open-interest_bitfinex_btc_usdt_open_interest_...          17
# 1639                    block-interval_block_interval_2          17
# 15    liquidations_all_exchange_all_symbol_long_liqu...          17
# 1          taker-buy-sell-stats_bybit_taker_sell_volume          17
# 87                        block-interval_block_interval          15
# 1650                          block-bytes_block_bytes_5          15
# 1640                    block-interval_block_interval_5          15
# 80           tokens-transferred_tokens_transferred_mean          15
# 1994  open-interest_bybit_btc_usdt_open_interest_diff_2          14
# 1962  open-interest_okx_btc_usdt_open_interest_pct_c...          14
# 173                        funding_rate_position_change          14
# 12         taker-buy-sell-stats_binance_taker_buy_ratio          14
# 967   taker-buy-sell-stats_bitmex_taker_sell_volume_...          14
# 156   open-interest_all_exchange_all_symbol_open_int...          14
# 1138    taker-buy-sell-stats_bitmex_taker_sell_ratio_WT          14
# 1600      tokens-transferred_tokens_transferred_total_5          14
# 1946  open-interest_all_exchange_all_symbol_open_int...          14
# 1386   open-interest_bitfinex_btc_usdt_open_interest_23          13
# 322   open-interest_bitfinex_btc_usdt_open_interest_...          13
# 2002  open-interest_bitfinex_btc_usdt_open_interest_...          13
# 1961  open-interest_okx_btc_usdt_open_interest_pct_c...          13
# 157   open-interest_binance_btc_usd_open_interest_pc...          13
# 1971  open-interest_deribit_btc_usd_open_interest_pc...          13
# 159   open-interest_okx_btc_usdt_open_interest_pct_c...          13
# 0           taker-buy-sell-stats_bybit_taker_buy_volume          13
# 1972  open-interest_deribit_btc_usd_open_interest_pc...          13
# 1436          addresses-count_addresses_count_active_23          13
# 51           taker-buy-sell-stats_okx_taker_sell_volume          13
# 1710     taker-buy-sell-stats_bitmex_taker_buy_volume_5          13
# 2018                      liquidation_to_volume_ratio_1          12
# 1443         addresses-count_addresses_count_receiver_1          12
# 1463         taker-buy-sell-stats_okx_taker_buy_ratio_1          12
# 1562      transactions-count_transactions_count_mean_47          12
# 1018  open-interest_deribit_btc_usd_open_interest_pc...          12
# 52             taker-buy-sell-stats_okx_taker_buy_ratio          12
# 1649                          block-bytes_block_bytes_2          12
# 50            taker-buy-sell-stats_okx_taker_buy_volume          12
# 1651                         block-bytes_block_bytes_23          12
# 1617                               hashrate_hashrate_47          12
# 1826                 funding-rates_okx_funding_rates_23          11
# 1528   taker-buy-sell-stats_deribit_taker_sell_volume_1          11
# 1534     taker-buy-sell-stats_deribit_taker_buy_ratio_2          11
# 1446        addresses-count_addresses_count_receiver_23          11
# 1192  open-interest_bybit_btc_usdt_open_interest_dif...          11
# 1599      tokens-transferred_tokens_transferred_total_2          11
# 1194  open-interest_bitfinex_btc_usdt_open_interest_...          11
# 1472       taker-buy-sell-stats_okx_taker_sell_ratio_47          11
# 364   addresses-count_addresses_count_active_rolling...          11
# 123   liquidations_binance_all_symbol_short_liquidat...          11
# 149                               buy_sell_volume_ratio          11
# 1611    tokens-transferred_tokens_transferred_median_23          11
# 1889                          blockreward_blockreward_2          11
# 21     taker-buy-sell-stats_htx_global_taker_buy_volume          11
# 1603       tokens-transferred_tokens_transferred_mean_1          11
# 829   open-interest_bitfinex_btc_usdt_open_interest_...          11
# 1718      taker-buy-sell-stats_bitmex_taker_buy_ratio_1          11
# 1208     taker-buy-sell-stats_bybit_taker_sell_volume_1          11
# 1215       taker-buy-sell-stats_bybit_taker_buy_ratio_5          11
# 1212    taker-buy-sell-stats_bybit_taker_sell_volume_47          11
# 2026                           liquidation_usd_ratio_23          11
# 363   addresses-count_addresses_count_active_rolling...          11
# 66         taker-buy-sell-stats_deribit_taker_buy_ratio          10
# 2031                    funding_rate_position_change_23          10
# 1282  liquidations_all_exchange_all_symbol_long_liqu...          10
# 846              liquidation_usd_ratio_rolling_mean_12h          10
# 1319  taker-buy-sell-stats_htx_global_taker_buy_ratio_2          10
# 1536    taker-buy-sell-stats_deribit_taker_buy_ratio_23          10
# 825   open-interest_bitfinex_btc_usdt_open_interest_...          10
# 1030          funding_rate_position_change_moving_avg_7          10
# 2019                      liquidation_to_volume_ratio_2          10
# 1314  taker-buy-sell-stats_htx_global_taker_sell_vol...          10
# 169   open-interest_bybit_all_symbol_open_interest_p...          10
# 79          tokens-transferred_tokens_transferred_total          10
# 71           transactions-count_transactions_count_mean          10
# 1952  open-interest_binance_btc_usd_open_interest_pc...          10
# 1326  taker-buy-sell-stats_htx_global_taker_sell_rat...          10
# 160       open-interest_okx_btc_usdt_open_interest_diff          10
# 23      taker-buy-sell-stats_htx_global_taker_buy_ratio          10
# 1955  open-interest_binance_btc_usd_open_interest_di...          10
# 1598      tokens-transferred_tokens_transferred_total_1          10
# 1238  taker-buy-sell-stats_all_exchange_taker_buy_ra...          10
# 1969  open-interest_deribit_btc_usd_open_interest_pc...          10
# 1951  open-interest_binance_btc_usd_open_interest_pc...          10
# 1966   open-interest_okx_btc_usdt_open_interest_diff_23          10
# 1205      taker-buy-sell-stats_bybit_taker_buy_volume_5          10
# 1322  taker-buy-sell-stats_htx_global_taker_buy_rati...           9
# 1964    open-interest_okx_btc_usdt_open_interest_diff_2           9
# 1609     tokens-transferred_tokens_transferred_median_2           9
# 1976  open-interest_deribit_btc_usd_open_interest_di...           9
# 1405                                  fees_fees_total_5           9
# 1556     transactions-count_transactions_count_total_23           9
# 1648                          block-bytes_block_bytes_1           9
# 138                         blockreward_blockreward_usd           9
# 443   taker-buy-sell-stats_deribit_taker_buy_ratio_r...           9
# 1312  taker-buy-sell-stats_htx_global_taker_buy_volu...           9
# 137                             blockreward_blockreward           9
# 1970  open-interest_deribit_btc_usd_open_interest_pc...           9
# 1348  liquidations_binance_btc_usdt_short_liquidatio...           9
# 1941  open-interest_all_exchange_all_symbol_open_int...           9
# 144                                liquidation_usd_diff           9
# 864                 supply_change_rate_rolling_mean_48h           9
# 158    open-interest_binance_btc_usd_open_interest_diff           9
# 166     open-interest_bybit_btc_usdt_open_interest_diff           9
# 1561      transactions-count_transactions_count_mean_23           9
# 170   open-interest_bybit_all_symbol_open_interest_diff           9
# 1537    taker-buy-sell-stats_deribit_taker_buy_ratio_47           9
# 802   open-interest_deribit_btc_usd_open_interest_pc...           9
# 7     taker-buy-sell-stats_all_exchange_taker_buy_ratio           9
# 2015  open-interest_bybit_all_symbol_open_interest_d...           9
# 1266    taker-buy-sell-stats_binance_taker_buy_ratio_23           9
# 725             blockreward_blockreward_rolling_mean_6h           9
# 1203      taker-buy-sell-stats_bybit_taker_buy_volume_1           9
# 1460       taker-buy-sell-stats_okx_taker_sell_volume_5           9
# 1217      taker-buy-sell-stats_bybit_taker_buy_ratio_47           9
# 1347  liquidations_binance_btc_usdt_long_liquidation...           9
# 785   open-interest_binance_btc_usd_open_interest_pc...           9
# 1255    taker-buy-sell-stats_binance_taker_buy_volume_5           9
# 749                    liquidation_diff_rolling_mean_6h           9
# 2021                     liquidation_to_volume_ratio_23           9
# 2024                            liquidation_usd_ratio_2           9
# 1069  liquidations_okx_btc_usdt_short_liquidations_u...           9
# 1713    taker-buy-sell-stats_bitmex_taker_sell_volume_1           9
# 1466        taker-buy-sell-stats_okx_taker_buy_ratio_23           9
# 1317  taker-buy-sell-stats_htx_global_taker_sell_vol...           9
# 278   taker-buy-sell-stats_htx_global_taker_buy_sell...           9
# 1973  open-interest_deribit_btc_usd_open_interest_di...           9
# 2000  open-interest_bitfinex_btc_usdt_open_interest_...           8
# 1435           addresses-count_addresses_count_active_5           8
# 1271   taker-buy-sell-stats_binance_taker_sell_ratio_23           8
# 1283  liquidations_all_exchange_all_symbol_short_liq...           8
# 1264     taker-buy-sell-stats_binance_taker_buy_ratio_2           8
# 1309  taker-buy-sell-stats_htx_global_taker_buy_volu...           8
# 1458       taker-buy-sell-stats_okx_taker_sell_volume_1           8
# 1605       tokens-transferred_tokens_transferred_mean_5           8
# 1614                                hashrate_hashrate_2           8
# 1997  open-interest_bybit_btc_usdt_open_interest_dif...           8
# 1977  open-interest_deribit_btc_usd_open_interest_di...           8
# 2005  open-interest_bitfinex_btc_usdt_open_interest_...           8
# 528      block-interval_block_interval_rolling_mean_48h           8
# 1468        taker-buy-sell-stats_okx_taker_sell_ratio_1           8
# 1727    taker-buy-sell-stats_bitmex_taker_sell_ratio_47           8
# 1722     taker-buy-sell-stats_bitmex_taker_buy_ratio_47           8
# 837   open-interest_bybit_all_symbol_open_interest_d...           8
# 1975  open-interest_deribit_btc_usd_open_interest_di...           8
# 1998  open-interest_bitfinex_btc_usdt_open_interest_...           8
# 970   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...           8
# 794   open-interest_okx_btc_usdt_open_interest_pct_c...           8
# 155   open-interest_all_exchange_all_symbol_open_int...           8
# 269   taker-buy-sell-stats_htx_global_taker_buy_rati...           8
# 1918                                 liquidation_diff_1           8
# 2027                           liquidation_usd_ratio_47           8
# 1956  open-interest_binance_btc_usd_open_interest_di...           8
# 1957  open-interest_binance_btc_usd_open_interest_di...           8
# 277   taker-buy-sell-stats_htx_global_taker_buy_sell...           8
# 852       funding_rate_position_change_rolling_mean_48h           8
# 48             addresses-count_addresses_count_receiver           8
# 70          transactions-count_transactions_count_total           8
# 1949  open-interest_binance_btc_usd_open_interest_pc...           8
# 2008  open-interest_bybit_all_symbol_open_interest_p...           8
# 1012  open-interest_all_exchange_all_symbol_open_int...           8
# 843        liquidation_to_volume_ratio_rolling_mean_24h           8
# 845               liquidation_usd_ratio_rolling_mean_6h           8
# 393   taker-buy-sell-stats_okx_taker_buy_sell_ratio_...           8
# 82                                    hashrate_hashrate           8
# 369   addresses-count_addresses_count_receiver_rolli...           8
# 362   addresses-count_addresses_count_active_rolling...           8
# 1958  open-interest_okx_btc_usdt_open_interest_pct_c...           8
# 1641                   block-interval_block_interval_23           8
# 452   taker-buy-sell-stats_deribit_taker_buy_sell_ra...           8
# 1441          addresses-count_addresses_count_sender_23           8
# 1465         taker-buy-sell-stats_okx_taker_buy_ratio_5           8
# 930   taker-buy-sell-stats_deribit_taker_sell_volume...           8
# 1235  taker-buy-sell-stats_all_exchange_taker_sell_v...           8
# 1216      taker-buy-sell-stats_bybit_taker_buy_ratio_23           8
# 1218      taker-buy-sell-stats_bybit_taker_sell_ratio_1           8
# 1339  liquidations_binance_btc_usdt_short_liquidatio...           8
# 1597         open-interest_okx_btc_usd_open_interest_47           8
# 1638                    block-interval_block_interval_1           8
# 1530   taker-buy-sell-stats_deribit_taker_sell_volume_5           8
# 1533     taker-buy-sell-stats_deribit_taker_buy_ratio_1           8
# 1029                 liquidation_usd_ratio_moving_avg_7           8
# 818   open-interest_bybit_btc_usdt_open_interest_pct...           8
# 2012  open-interest_bybit_all_symbol_open_interest_p...           8
# 1467        taker-buy-sell-stats_okx_taker_buy_ratio_47           8
# 594   taker-buy-sell-stats_bitmex_taker_sell_ratio_r...           8
# 464   transactions-count_transactions_count_mean_rol...           8
# 502   tokens-transferred_tokens_transferred_median_r...           7
# 2044                               supply_change_rate_2           7
# 782   open-interest_all_exchange_all_symbol_open_int...           7
# 418   liquidations_huobi_global_all_symbol_short_liq...           7
# 1937                           buy_sell_volume_ratio_47           7
# 1942  open-interest_all_exchange_all_symbol_open_int...           7
# 838   open-interest_bybit_all_symbol_open_interest_d...           7
# 179   taker-buy-sell-stats_bybit_taker_buy_volume_ro...           7
# 450   taker-buy-sell-stats_deribit_taker_buy_sell_ra...           7
# 2043                               supply_change_rate_1           7
# 1444         addresses-count_addresses_count_receiver_2           7
# 46               addresses-count_addresses_count_active           7
# 438   taker-buy-sell-stats_deribit_taker_sell_volume...           7
# 839   open-interest_bybit_all_symbol_open_interest_d...           7
# 1313  taker-buy-sell-stats_htx_global_taker_sell_vol...           7
# 789   open-interest_binance_btc_usd_open_interest_di...           7
# 496   tokens-transferred_tokens_transferred_total_ro...           7
# 498   tokens-transferred_tokens_transferred_mean_rol...           7
# 796   open-interest_okx_btc_usdt_open_interest_pct_c...           7
# 442   taker-buy-sell-stats_deribit_taker_buy_ratio_r...           7
# 8     taker-buy-sell-stats_all_exchange_taker_sell_r...           7
# 32          liquidations_okx_btc_usdt_long_liquidations           7
# 2006  open-interest_bitfinex_btc_usdt_open_interest_...           7
# 1601     tokens-transferred_tokens_transferred_total_23           7
# 161   open-interest_deribit_btc_usd_open_interest_pc...           7
# 233   taker-buy-sell-stats_binance_taker_buy_sell_ra...           7
# 1524    taker-buy-sell-stats_deribit_taker_buy_volume_2           7
# 1527   taker-buy-sell-stats_deribit_taker_buy_volume_47           7
# 1505  liquidations_huobi_global_all_symbol_short_liq...           7
# 805   open-interest_deribit_btc_usd_open_interest_di...           7
# 193   taker-buy-sell-stats_bybit_taker_buy_sell_rati...           7
# 1999  open-interest_bitfinex_btc_usdt_open_interest_...           7
# 1896                     blockreward_blockreward_usd_23           7
# 1897                     blockreward_blockreward_usd_47           7
# 1891                         blockreward_blockreward_23           7
# 1892                         blockreward_blockreward_47           7
# 1642                   block-interval_block_interval_47           7
# 1630         fees-transaction_fees_transaction_median_5           7
# 194   taker-buy-sell-stats_bybit_taker_buy_sell_rati...           7
# 213   taker-buy-sell-stats_all_exchange_taker_buy_se...           7
# 1308  taker-buy-sell-stats_htx_global_taker_buy_volu...           7
# 1991  open-interest_bybit_btc_usdt_open_interest_pct...           7
# 1988  open-interest_bybit_btc_usdt_open_interest_pct...           7
# 13        taker-buy-sell-stats_binance_taker_sell_ratio           7
# 2029                     funding_rate_position_change_2           7
# 835   open-interest_bybit_all_symbol_open_interest_p...           7
# 836   open-interest_bybit_all_symbol_open_interest_p...           7
# 1013  open-interest_all_exchange_all_symbol_open_int...           7
# 1894                      blockreward_blockreward_usd_2           7
# 101        taker-buy-sell-stats_bitmex_taker_buy_volume           7
# 1433           addresses-count_addresses_count_active_1           7
# 1481  open-interest_huobi_global_btc_usdt_open_inter...           7
# 1193  open-interest_bitfinex_btc_usdt_open_interest_...           7
# 1213       taker-buy-sell-stats_bybit_taker_buy_ratio_1           7
# 596   taker-buy-sell-stats_bitmex_taker_sell_ratio_r...           7
# 598   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...           7
# 2047                              supply_change_rate_47           7
# 968   taker-buy-sell-stats_bitmex_taker_buy_ratio_mo...           7
# 379   taker-buy-sell-stats_okx_taker_buy_volume_roll...           7
# 1024  open-interest_bitfinex_btc_usdt_open_interest_...           7
# 1026  open-interest_bybit_all_symbol_open_interest_p...           7
# 89                              block-bytes_block_bytes           7
# 1586  open-interest_huobi_global_all_symbol_open_int...           7
# 924   liquidations_huobi_global_all_symbol_long_liqu...           7
# 834   open-interest_bybit_all_symbol_open_interest_p...           7
# 1320  taker-buy-sell-stats_htx_global_taker_buy_ratio_5           7
# 1002               blockreward_blockreward_moving_avg_7           7
# 912   addresses-count_addresses_count_sender_moving_...           7
# 911   addresses-count_addresses_count_active_moving_...           7
# 873   taker-buy-sell-stats_all_exchange_taker_sell_r...           7
# 1210     taker-buy-sell-stats_bybit_taker_sell_volume_5           7
# 1926                            liquidation_usd_diff_23           7
# 1950  open-interest_binance_btc_usd_open_interest_pc...           7
# 494   tokens-transferred_tokens_transferred_total_ro...           7
# 216   taker-buy-sell-stats_all_exchange_taker_buy_se...           6
# 824   open-interest_bybit_btc_usdt_open_interest_dif...           6
# 1337  liquidations_binance_btc_usdt_long_liquidation...           6
# 1340  liquidations_binance_btc_usdt_short_liquidatio...           6
# 1237  taker-buy-sell-stats_all_exchange_taker_sell_v...           6
# 583   taker-buy-sell-stats_bitmex_taker_buy_volume_r...           6
# 2045                               supply_change_rate_5           6
# 2028                     funding_rate_position_change_1           6
# 2030                     funding_rate_position_change_5           6
# 2017  open-interest_bybit_all_symbol_open_interest_d...           6
# 29    liquidations_binance_btc_usdt_short_liquidatio...           6
# 1615                                hashrate_hashrate_5           6
# 1604       tokens-transferred_tokens_transferred_mean_2           6
# 1746     coinbase-premium-index_coinbase_premium_gap_23           6
# 1470        taker-buy-sell-stats_okx_taker_sell_ratio_5           6
# 1457       taker-buy-sell-stats_okx_taker_buy_volume_47           6
# 1459       taker-buy-sell-stats_okx_taker_sell_volume_2           6
# 1455        taker-buy-sell-stats_okx_taker_buy_volume_5           6
# 1442          addresses-count_addresses_count_sender_47           6
# 888   taker-buy-sell-stats_htx_global_taker_buy_rati...           6
# 790   open-interest_binance_btc_usd_open_interest_di...           6
# 781   open-interest_all_exchange_all_symbol_open_int...           6
# 280   taker-buy-sell-stats_htx_global_taker_buy_sell...           6
# 272   taker-buy-sell-stats_htx_global_taker_buy_rati...           6
# 589   taker-buy-sell-stats_bitmex_taker_buy_ratio_ro...           6
# 883   liquidations_all_exchange_all_symbol_short_liq...           6
# 874   taker-buy-sell-stats_all_exchange_taker_buy_se...           6
# 879   taker-buy-sell-stats_binance_taker_buy_sell_ra...           6
# 869   taker-buy-sell-stats_bybit_taker_buy_sell_rati...           6
# 444   taker-buy-sell-stats_deribit_taker_buy_ratio_r...           6
# 416   liquidations_huobi_global_all_symbol_long_liqu...           6
# 792   open-interest_binance_btc_usd_open_interest_di...           6
# 795   open-interest_okx_btc_usdt_open_interest_pct_c...           6
# 1362             funding-rates_deribit_funding_rates_47           6
# 787   open-interest_binance_btc_usd_open_interest_pc...           6
# 1349  liquidations_binance_btc_usdt_short_liquidatio...           6
# 1712    taker-buy-sell-stats_bitmex_taker_buy_volume_47           6
# 786   open-interest_binance_btc_usd_open_interest_pc...           6
# 801   open-interest_deribit_btc_usd_open_interest_pc...           6
# 806   open-interest_deribit_btc_usd_open_interest_di...           6
# 1289  liquidations_all_exchange_all_symbol_long_liqu...           6
# 446   taker-buy-sell-stats_deribit_taker_sell_ratio_...           6
# 533             block-bytes_block_bytes_rolling_mean_6h           6
# 108         coinbase-premium-index_coinbase_premium_gap           6
# 798   open-interest_okx_btc_usdt_open_interest_diff_...           6
# 1315  taker-buy-sell-stats_htx_global_taker_sell_vol...           6
# 755               liquidation_usd_diff_rolling_mean_24h           6
# 674    funding-rates_okx_funding_rates_rolling_mean_12h           6
# 1606      tokens-transferred_tokens_transferred_mean_23           6
# 1232  taker-buy-sell-stats_all_exchange_taker_buy_vo...           6
# 68    taker-buy-sell-stats_deribit_taker_buy_sell_ratio           6
# 1948  open-interest_binance_btc_usd_open_interest_pc...           6
# 1943  open-interest_all_exchange_all_symbol_open_int...           6
# 124                     funding-rates_okx_funding_rates           6
# 192   taker-buy-sell-stats_bybit_taker_sell_ratio_ro...           6
# 1559       transactions-count_transactions_count_mean_2           6
# 235   taker-buy-sell-stats_binance_taker_buy_sell_ra...           6
# 1288  liquidations_all_exchange_all_symbol_long_liqu...           6
# 1916      open-interest_okx_all_symbol_open_interest_23           6
# 1890                          blockreward_blockreward_5           6
# 1893                      blockreward_blockreward_usd_1           6
# 753                liquidation_usd_diff_rolling_mean_6h           6
# 863                 supply_change_rate_rolling_mean_24h           6
# 851       funding_rate_position_change_rolling_mean_24h           6
# 1708     taker-buy-sell-stats_bitmex_taker_buy_volume_1           6
# 1219      taker-buy-sell-stats_bybit_taker_sell_ratio_2           6
# 833   open-interest_bybit_all_symbol_open_interest_p...           6
# 1750    coinbase-premium-index_coinbase_premium_index_5           6
# 1196  open-interest_bybit_all_symbol_open_interest_d...           6
# 1100    taker-buy-sell-stats_deribit_taker_buy_ratio_WT           6
# 386   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...           6
# 388   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...           6
# 154                                                hour           6
# 1540    taker-buy-sell-stats_deribit_taker_sell_ratio_5           6
# 969   taker-buy-sell-stats_bitmex_taker_sell_ratio_m...           6
# 952          block-interval_block_interval_moving_avg_7           6
# 1585  open-interest_huobi_global_all_symbol_open_int...           6
# 2003  open-interest_bitfinex_btc_usdt_open_interest_...           6
# 597   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...           6
# 590   taker-buy-sell-stats_bitmex_taker_buy_ratio_ro...           6
# 536            block-bytes_block_bytes_rolling_mean_48h           6
# 1996  open-interest_bybit_btc_usdt_open_interest_dif...           6
# 2007  open-interest_bitfinex_btc_usdt_open_interest_...           6
# 3           taker-buy-sell-stats_bybit_taker_sell_ratio           6
# 1953  open-interest_binance_btc_usd_open_interest_di...           6
# 74    liquidations_huobi_global_btc_usdt_long_liquid...           6
# 1016  open-interest_okx_btc_usdt_open_interest_pct_c...           6
# 76    open-interest_huobi_global_all_symbol_open_int...           6
# 1019  open-interest_deribit_btc_usd_open_interest_di...           6
# 1827                 funding-rates_okx_funding_rates_47           5
# 1823                  funding-rates_okx_funding_rates_1           5
# 1734  liquidations_bybit_all_symbol_long_liquidations_2           5
# 1721     taker-buy-sell-stats_bitmex_taker_buy_ratio_23           5
# 1725     taker-buy-sell-stats_bitmex_taker_sell_ratio_5           5
# 1220      taker-buy-sell-stats_bybit_taker_sell_ratio_5           5
# 1963    open-interest_okx_btc_usdt_open_interest_diff_1           5
# 1209     taker-buy-sell-stats_bybit_taker_sell_volume_2           5
# 1715    taker-buy-sell-stats_bitmex_taker_sell_volume_5           5
# 1716   taker-buy-sell-stats_bitmex_taker_sell_volume_23           5
# 1686  liquidations_okx_all_symbol_long_liquidations_...           5
# 1402                        fees_fees_block_mean_usd_47           5
# 1095        open-interest_okx_btc_usdt_open_interest_WT           5
# 731        blockreward_blockreward_usd_rolling_mean_24h           5
# 783   open-interest_all_exchange_all_symbol_open_int...           5
# 1927                            liquidation_usd_diff_47           5
# 1368     liquidations_okx_btc_usdt_short_liquidations_1           5
# 207   taker-buy-sell-stats_all_exchange_taker_buy_ra...           5
# 195   taker-buy-sell-stats_bybit_taker_buy_sell_rati...           5
# 1542   taker-buy-sell-stats_deribit_taker_sell_ratio_47           5
# 1531  taker-buy-sell-stats_deribit_taker_sell_volume_23           5
# 1619           fees-transaction_fees_transaction_mean_2           5
# 1469        taker-buy-sell-stats_okx_taker_sell_ratio_2           5
# 1462      taker-buy-sell-stats_okx_taker_sell_volume_47           5
# 1438           addresses-count_addresses_count_sender_1           5
# 1612    tokens-transferred_tokens_transferred_median_47           5
# 185   taker-buy-sell-stats_bybit_taker_buy_ratio_rol...           5
# 188   taker-buy-sell-stats_bybit_taker_buy_ratio_rol...           5
# 177   taker-buy-sell-stats_bybit_taker_buy_volume_ro...           5
# 180   taker-buy-sell-stats_bybit_taker_buy_volume_ro...           5
# 916   taker-buy-sell-stats_okx_taker_sell_volume_mov...           5
# 890   taker-buy-sell-stats_htx_global_taker_buy_sell...           5
# 966   taker-buy-sell-stats_bitmex_taker_buy_volume_m...           5
# 2022                     liquidation_to_volume_ratio_47           5
# 28    liquidations_binance_btc_usdt_long_liquidation...           5
# 587   taker-buy-sell-stats_bitmex_taker_sell_volume_...           5
# 569   open-interest_bybit_btc_usdt_open_interest_rol...           5
# 560   liquidations_okx_all_symbol_short_liquidations...           5
# 564   liquidations_okx_all_symbol_long_liquidations_...           5
# 1960  open-interest_okx_btc_usdt_open_interest_pct_c...           5
# 1915       open-interest_okx_all_symbol_open_interest_5           5
# 1965    open-interest_okx_btc_usdt_open_interest_diff_5           5
# 526      block-interval_block_interval_rolling_mean_12h           5
# 497   tokens-transferred_tokens_transferred_mean_rol...           5
# 47               addresses-count_addresses_count_sender           5
# 5     taker-buy-sell-stats_all_exchange_taker_buy_vo...           5
# 370   addresses-count_addresses_count_receiver_rolli...           5
# 361   addresses-count_addresses_count_active_rolling...           5
# 592   taker-buy-sell-stats_bitmex_taker_buy_ratio_ro...           5
# 945   tokens-transferred_tokens_transferred_mean_mov...           5
# 1523    taker-buy-sell-stats_deribit_taker_buy_volume_1           5
# 1526   taker-buy-sell-stats_deribit_taker_buy_volume_23           5
# 1496  liquidations_huobi_global_all_symbol_short_liq...           5
# 240   liquidations_all_exchange_all_symbol_long_liqu...           5
# 247   liquidations_all_exchange_all_symbol_long_liqu...           5
# 236   taker-buy-sell-stats_binance_taker_buy_sell_ra...           5
# 225   taker-buy-sell-stats_binance_taker_buy_ratio_r...           5
# 1081          addresses-count_addresses_count_sender_WT           5
# 387   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...           5
# 841         liquidation_to_volume_ratio_rolling_mean_6h           5
# 847              liquidation_usd_ratio_rolling_mean_24h           5
# 1171                         blockreward_blockreward_WT           5
# 1113     tokens-transferred_tokens_transferred_total_WT           5
# 595   taker-buy-sell-stats_bitmex_taker_sell_ratio_r...           5
# 18    liquidations_all_exchange_all_symbol_short_liq...           5
# 1342  liquidations_binance_btc_usdt_short_liquidatio...           5
# 1321  taker-buy-sell-stats_htx_global_taker_buy_rati...           5
# 1318  taker-buy-sell-stats_htx_global_taker_buy_ratio_1           5
# 305   liquidations_okx_btc_usdt_long_liquidations_ro...           5
# 944   tokens-transferred_tokens_transferred_total_mo...           5
# 1591             funding-rates_binance_funding_rates_23           5
# 1570  liquidations_huobi_global_btc_usdt_short_liqui...           5
# 208   taker-buy-sell-stats_all_exchange_taker_buy_ra...           5
# 212   taker-buy-sell-stats_all_exchange_taker_sell_r...           5
# 1070   open-interest_bitfinex_btc_usdt_open_interest_WT           5
# 1101   taker-buy-sell-stats_deribit_taker_sell_ratio_WT           5
# 1089  open-interest_huobi_global_btc_usdt_open_inter...           5
# 867   taker-buy-sell-stats_bybit_taker_buy_ratio_mov...           5
# 385   taker-buy-sell-stats_okx_taker_buy_ratio_rolli...           5
# 601   liquidations_bybit_all_symbol_long_liquidation...           5
# 1360              funding-rates_deribit_funding_rates_5           5
# 1363      liquidations_okx_btc_usdt_long_liquidations_1           5
# 1356    open-interest_binance_btc_usdt_open_interest_23           5
# 1350  liquidations_binance_btc_usdt_short_liquidatio...           5
# 439   taker-buy-sell-stats_deribit_taker_sell_volume...           5
# 1445         addresses-count_addresses_count_receiver_5           5
# 1437          addresses-count_addresses_count_active_47           5
# 338                    fees_fees_total_rolling_mean_12h           5
# 284   liquidations_binance_btc_usdt_long_liquidation...           5
# 270   taker-buy-sell-stats_htx_global_taker_buy_rati...           5
# 262   taker-buy-sell-stats_htx_global_taker_buy_volu...           5
# 797   open-interest_okx_btc_usdt_open_interest_diff_...           5
# 780   open-interest_all_exchange_all_symbol_open_int...           5
# 1974  open-interest_deribit_btc_usd_open_interest_di...           5
# 2016  open-interest_bybit_all_symbol_open_interest_d...           5
# 1535     taker-buy-sell-stats_deribit_taker_buy_ratio_5           5
# 1204      taker-buy-sell-stats_bybit_taker_buy_volume_2           5
# 1242  taker-buy-sell-stats_all_exchange_taker_buy_ra...           5
# 1260   taker-buy-sell-stats_binance_taker_sell_volume_5           5
# 1258   taker-buy-sell-stats_binance_taker_sell_volume_1           5
# 1257   taker-buy-sell-stats_binance_taker_buy_volume_47           5
# 1272   taker-buy-sell-stats_binance_taker_sell_ratio_47           5
# 1281  liquidations_all_exchange_all_symbol_long_liqu...           5
# 103         taker-buy-sell-stats_bitmex_taker_buy_ratio           5
# 666   liquidations_binance_all_symbol_long_liquidati...           5
# 667   liquidations_binance_all_symbol_long_liquidati...           5
# 671   liquidations_binance_all_symbol_short_liquidat...           5
# 458   transactions-count_transactions_count_total_ro...           5
# 600   taker-buy-sell-stats_bitmex_taker_buy_sell_rat...           5
# 1302  open-interest_huobi_global_btc_usd_open_intere...           5
# 120   liquidations_binance_all_symbol_long_liquidations           5
# 1714    taker-buy-sell-stats_bitmex_taker_sell_volume_2           5
# 38                                 fees_fees_block_mean           4
# 1968  open-interest_deribit_btc_usd_open_interest_pc...           4
# 1338  liquidations_binance_btc_usdt_short_liquidatio...           4
# 1343  liquidations_binance_btc_usdt_long_liquidation...           4
# 2014  open-interest_bybit_all_symbol_open_interest_d...           4
# 1122        funding-rates_huobi_global_funding_rates_WT           4
# 1065             funding-rates_deribit_funding_rates_WT           4
# 1532  taker-buy-sell-stats_deribit_taker_sell_volume_47           4
# 1501  liquidations_huobi_global_all_symbol_long_liqu...           4
# 1046    taker-buy-sell-stats_binance_taker_buy_ratio_WT           4
# 607   liquidations_bybit_all_symbol_long_liquidation...           4
# 611   coinbase-premium-index_coinbase_premium_gap_ro...           4
# 1489  liquidations_huobi_global_all_symbol_long_liqu...           4
# 1487        funding-rates_all_exchange_funding_rates_47           4
# 1473    taker-buy-sell-stats_okx_taker_buy_sell_ratio_1           4
# 26      liquidations_binance_btc_usdt_long_liquidations           4
# 1485         funding-rates_all_exchange_funding_rates_5           4
# 1488  liquidations_huobi_global_all_symbol_long_liqu...           4
# 1014  open-interest_binance_btc_usd_open_interest_pc...           4
# 1053  open-interest_huobi_global_btc_usd_open_intere...           4
# 1525    taker-buy-sell-stats_deribit_taker_buy_volume_5           4

# %% [markdown]
# # Cross Validation 활용 부분

# %%
# # 교차 검증 수행
# cv_results = lgb.cv(
#     params,
#     train_data,
#     num_boost_round=1000,
#     nfold=5,
#     stratified=True,
#     callbacks=[lgb.early_stopping(stopping_rounds=50)],
#     return_cvbooster=True
# )

# # 교차 검증 결과 출력
# print('Best num_boost_round:', len(cv_results['valid multi_logloss-mean']))
# print('Best CV score:', cv_results['valid multi_logloss-mean'][-1])

# %%
# # CVBooster 객체 가져오기
# cv_booster = cv_results['cvbooster']

# # 새로운 데이터에 대한 예측
# predictions = cv_booster.predict(x_train.values)

# %%
# # 1. 예측값 평균 계산
# avg_predictions = np.mean(predictions, axis=0)

# # 2. 클래스 예측
# y_valid_pred_class = np.argmax(avg_predictions, axis=1)

# # 3. 성능 평가
# accuracy = accuracy_score(y_valid, y_valid_pred_class)
# auroc = roc_auc_score(y_valid, avg_predictions, multi_class="ovr")

# print(f"acc: {accuracy}, auroc: {auroc}")

# # 추가된 confusion matrix 구현 부분
# evaluate_model(y_valid, y_valid_pred_class, "cv_lgb_model")

# %% [markdown]
# # 원본의 재학습, 추론, 결과 파일 생성 부분

# %%
# # performance 체크후 전체 학습 데이터로 다시 재학습
# x_train = train_df.drop(["target", "ID"], axis = 1)
# y_train = train_df["target"].astype(int)
# train_data = lgb.Dataset(x_train, label=y_train)
# lgb_model = lgb.train(
#     params=params,
#     train_set=train_data,
# )

# %% [markdown]
# ### Inference

# %%
# # lgb predict
# y_test_pred = lgb_model.predict(test_df.drop(["target", "ID"], axis = 1))
# y_test_pred_class = np.argmax(y_test_pred, axis = 1)

# %% [markdown]
# ### Output File Save

# %%
# # output file 할당후 save 
# submission = submission.assign(target = y_test_pred_class)
# submission.to_csv("output.csv", index=False)

# %% [markdown]
# # 영찬이 앙상블 부분

# %% [markdown]
# ### LGBM based Bagging 학습

# %%
# from sklearn.ensemble import BaggingClassifier
# from lightgbm import LGBMClassifier

# # LightGBM을 기반으로 하는 Bagging Classifier
# bagging_model = BaggingClassifier(
#     base_estimator=LGBMClassifier(**params),
#     n_estimators=10,  # Bagging에서 사용할 모델 수
#     random_state=42
# )

# # 학습
# bagging_model.fit(x_train, y_train)

# # 예측
# y_valid_pred = bagging_model.predict(x_valid)

# # 평가
# accuracy = accuracy_score(y_valid, y_valid_pred)
# auroc = roc_auc_score(y_valid, bagging_model.predict_proba(x_valid), multi_class="ovr")

# print(f"Bagging - acc: {accuracy}, auroc: {auroc}")

# %%
# from lightgbm import LGBMClassifier

# # train_test_split 으로 valid set, train set 분리
# x_train, x_valid, y_train, y_valid = train_test_split(
#     train_df.drop(["target", "ID"], axis = 1), 
#     train_df["target"].astype(int), 
#     test_size=0.2,
#     random_state=42,
# )

# # LightGBM 모델 생성 및 학습
# lgb_model = LGBMClassifier(
#     boosting_type="gbdt",
#     objective="multiclass",
#     num_class=4,
#     num_leaves=50,
#     learning_rate=0.05,
#     n_estimators=30,
#     random_state=42,
#     verbose=-1
# )

# lgb_model.fit(
#     x_train, 
#     y_train,
#     eval_set=[(x_valid, y_valid)],
#     eval_metric='multi_logloss'
# )

# %% [markdown]
# #### XGBoost 학습

# %%
# import xgboost as xgb
# from sklearn.ensemble import VotingClassifier

# # train_test_split 으로 valid set, train set 분리
# x_train, x_valid, y_train, y_valid = train_test_split(
#     train_df.drop(["target", "ID"], axis = 1), 
#     train_df["target"].astype(int), 
#     test_size=0.2,
#     random_state=42,
# )

# xgb_params = {
#     'objective': 'multi:softprob',
#     'num_class': 4,
#     'learning_rate': 0.05,
#     'max_depth': 6,
#     'n_estimators': 100,
#     'random_state': 42
# }

# # XGBoost 모델 학습 및 성능 체크
# xgb_model = xgb.XGBClassifier(**xgb_params)
# xgb_model.fit(x_train, y_train)

# %% [markdown]
# #### Ensenble

# %%
# from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier
# from sklearn.model_selection import cross_val_score
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import KFold
# from sklearn.base import BaseEstimator, ClassifierMixin, clone
# from sklearn.utils.validation import check_X_y, check_array, check_is_fitted
# from sklearn.utils.multiclass import unique_labels

# rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# # 데이터 준비
# X = train_df.drop(["target", "ID"], axis=1)
# y = train_df["target"].astype(int)

# # 교차 검증을 위한 KFold 정의
# kf = KFold(n_splits=5, shuffle=True, random_state=42)

# # 1. Voting 앙상블
# voting_hard = VotingClassifier(
#     estimators=[('lgb', lgb_model), ('xgb', xgb_model), ('rf', rf_model)],
#     voting='hard'
# )

# voting_soft = VotingClassifier(
#     estimators=[('lgb', lgb_model), ('xgb', xgb_model), ('rf', rf_model)],
#     voting='soft'
# )

# # 2. Bagging 앙상블
# bagging = BaggingClassifier(base_estimator=lgb_model, n_estimators=10, random_state=42)

# # 3. Stacking 앙상블

# class StackingEnsemble(BaseEstimator, ClassifierMixin):
#     def __init__(self, base_models, meta_model, n_folds=5):
#         self.base_models = base_models
#         self.meta_model = meta_model
#         self.n_folds = n_folds

#     def fit(self, X, y):
#         # Check that X and y have correct shape
#         X, y = check_X_y(X, y)
#         # Store the classes seen during fit
#         self.classes_ = unique_labels(y)

#         self.base_models_ = [list() for _ in self.base_models]
#         self.meta_model_ = clone(self.meta_model)
#         kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=42)
        
#         out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        
#         for i, model in enumerate(self.base_models):
#             for train_index, holdout_index in kfold.split(X, y):
#                 instance = clone(model)
#                 self.base_models_[i].append(instance)
#                 instance.fit(X[train_index], y[train_index])
#                 y_pred = instance.predict_proba(X[holdout_index])
#                 out_of_fold_predictions[holdout_index, i] = y_pred[:, 1]
        
#         self.meta_model_.fit(out_of_fold_predictions, y)
#         return self

#     def predict(self, X):
#         # Check is fit had been called
#         check_is_fitted(self)
#         # Input validation
#         X = check_array(X)
#         meta_features = np.column_stack([
#             np.column_stack([model.predict_proba(X)[:, 1] for model in base_models]).mean(axis=1)
#             for base_models in self.base_models_ ])
#         return self.meta_model_.predict(meta_features)

#     def predict_proba(self, X):
#         # Check is fit had been called
#         check_is_fitted(self)
#         # Input validation
#         X = check_array(X)
#         meta_features = np.column_stack([
#             np.column_stack([model.predict_proba(X)[:, 1] for model in base_models]).mean(axis=1)
#             for base_models in self.base_models_ ])
#         return self.meta_model_.predict_proba(meta_features)

# stacking = StackingEnsemble(
#     base_models=(lgb_model, xgb_model, rf_model),
#     meta_model=LogisticRegression()
# )

# from sklearn.model_selection import cross_val_predict

# accuracy_scores = cross_val_score(stacking, X, y, cv=kf, scoring='accuracy', error_score='raise')
# # AUROC 계산
# if hasattr(stacking, "predict_proba"):
#     y_pred_proba = cross_val_predict(stacking, X, y, cv=kf, method='predict_proba')
#     auroc_score = roc_auc_score(y, y_pred_proba, multi_class='ovr')
# else:
#     auroc_score = None

# print("Stacking")
# print(f"  - 평균 정확도: {accuracy_scores.mean()} (+/- {accuracy_scores.std() * 2})")
# if auroc_score:
#     print(f"  - AUROC: {auroc_score}")
# else:
#     print("  - AUROC: Not available")
# print()

# %%
# from sklearn.metrics import roc_auc_score
# from sklearn.model_selection import cross_val_predict

# # 모델 리스트 (VotingHard 제외)
# models = [lgb_model, xgb_model, rf_model, voting_soft, bagging]
# model_names = ['LightGBM', 'XGBoost', 'RandomForest', 'VotingSoft', 'Bagging']

# # 각 모델의 교차 검증 수행
# for name, model in zip(model_names, models):
#     # 정확도 계산
#     accuracy_scores = cross_val_score(model, X, y, cv=kf, scoring='accuracy')
    
#     # AUROC 계산
#     if hasattr(model, "predict_proba"):
#         y_pred_proba = cross_val_predict(model, X, y, cv=kf, method='predict_proba')
#         auroc_score = roc_auc_score(y, y_pred_proba, multi_class='ovr')
#     else:
#         auroc_score = None
    
#     print(f"{name}:")
#     print(f"  - 평균 정확도: {accuracy_scores.mean()} (+/- {accuracy_scores.std() * 2})")
#     if auroc_score:
#         print(f"  - AUROC: {auroc_score}")
#     else:
#         print("  - AUROC: Not available")
#     print()

# %%
# # 최종 모델 선택 및 전체 데이터로 학습 (AUROC 기준)
# best_model = models[np.argmax([
#     roc_auc_score(y, cross_val_predict(model, X, y, cv=kf, method='predict_proba'), multi_class='ovr')
#     if hasattr(model, "predict_proba") else 0 
#     for model in models
# ])]

# best_model.fit(X, y)

# # 테스트 데이터에 대한 예측
# X_test = test_df.drop(["target", "ID"], axis=1)
# y_test_pred = best_model.predict(X_test)
# if hasattr(best_model, "predict_proba"):
#     y_test_pred_proba = best_model.predict_proba(X_test)

# # 제출 파일 생성
# submission = submission.assign(target=y_test_pred)
# submission.to_csv("output_best_ensemble.csv", index=False)

# print(f"Best model: {type(best_model).__name__}")

# %% [markdown]
# ### Inference

# %% [markdown]
# 앙상블의 inference & save 과정.

# %%
# # performance 체크후 전체 학습 데이터로 다시 재학습 - LGBM Bagging(알아서 주석 빼고 실행)

# x_train = train_df.drop(["target", "ID"], axis = 1)
# y_train = train_df["target"].astype(int)
# train_data = lgb.Dataset(x_train, label=y_train)
# bagging_model.fit(x_train, y_train)

# y_test_pred = bagging_model.predict(test_df.drop(["target", "ID"], axis = 1))


# submission = submission.assign(target = y_test_pred_class)
# submission.to_csv("0925_median_output.csv", index=False)
